# %%
using ODBC
using DataFrames
using DSWB
using Formatting

dsn = "dswb-natgeo" # Redshift endpoint
table = "beacons_4744" # beacon table name
tableRt = "beacons_4744_rt"

# Connect to Beacon Data
setRedshiftEndpoint(dsn)
setTable(table)
# Out:
# Redshift endpoint set: 2017-09-11T16:53:50
# "beacons_4744"

# %%
include("/data/notebook_home/Production/Lib/Include-Package-v1.0.jl")
include("/data/notebook_home/Production/Bodies/Group-NatGeo-Site-Sql-Data-Mining-Body-v1.0.jl")

#timeVariables(2017,6,8,10,59,2017,6,8,12,59)
#weeklyTimeVariables(days=7)
yesterdayTimeVariables()
;
# Out:
# September 10, 2017 06:59:00 to September 10, 2017 16:59:00 Local Time
# September 10, 2017 10:59:00 to September 10, 2017 20:59:00 UTC Time

# %%
UP = UrlParamsInit()
UP.beaconTable = table   #table
UP.resourceTable = tableRt
UP.btView = "$(table)_sql_user_agent_view"
UP.rtView = "$(tableRt)_sql_user_agent_view"
UP.pageGroup = "News Article"   #productPageGroup
UP.urlRegEx = "%"   #localUrl
UP.deviceType = "%"

SG = SoastaGraphsInit()
customer = "Nat Geo" 
SG.customer = customer

SP = ShowParamsInit()
SP.debugLevel = 10;
SP.debug = true;
;

LV = LocalVars(0)
LV.linesOutput = 1000
;

# %%
defaultTableGNGSSDM(tv,UP)
;
# Out:
# beacons_4744_sql_user_agent_view count is 92039

# %%
test1GNGSSDM(UP,LV)
;
# Out:
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">url</th> <th class=\"cell-2\" style=\"\">count</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">http://news.nationalgeographic.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">92,039</td></tr>\n    \n    \n    </tbody>\n")

# %%
testUserAgentGNGSSDM(UP,LV)
;
# Out:
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">count</th> <th class=\"cell-2\" style=\"\">user agent raw</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"text-align:right;\">7,901</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">6,388</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_3 like Mac OS X) AppleWebKit/603.3.8 (KHTML, like Gecko) Version/10.0 Mobile/14G60 Safari/602.1</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">2,838</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (iPad; CPU OS 10_3_3 like Mac OS X) AppleWebKit/603.3.8 (KHTML, like Gecko) Version/10.0 Mobile/14G60 Safari/602.1</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">2,796</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">2,108</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/603.3.8 (KHTML, like Gecko) Version/10.1.2 Safari/603.3.8</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">1,564</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36 Edge/15.15063</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">1,445</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 10.0; WOW64; rv:55.0) Gecko/20100101 Firefox/55.0</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">1,175</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">988</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">845</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like Mac OS X) AppleWebKit/603.2.4 (KHTML, like Gecko) Version/10.0 Mobile/14F89 Safari/602.1</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">787</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">778</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 6.1; WOW64; rv:55.0) Gecko/20100101 Firefox/55.0</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">707</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">676</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Version/9.0 Mobile/13G36 Safari/601.1</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">577</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (compatible; AhrefsBot/5.2; +http://ahrefs.com/robot/)</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">566</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.79 Safari/537.36 Edge/14.14393</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">563</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/603.3.8 (KHTML, like Gecko) Version/10.1.2 Safari/603.3.8</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">560</td> <td class=\"cell-2\" style=\"\">Mozilla/5.0 (iPhone; CPU iPhone  ...

# %%
q = query(""" drop view if exists $(UP.btView);""")
q = query(""" drop view if exists $(UP.rtView);""")
;
