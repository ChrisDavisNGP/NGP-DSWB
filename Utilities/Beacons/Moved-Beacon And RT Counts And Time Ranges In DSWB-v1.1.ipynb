# %% [markdown]
# ***
# ## Beacons And RT Counts And Time Ranges In DSWB
# ***
# # Use this to find the range of data available.  Beacon table has a much longer duration so times may vary for both

# %%
using DSWB
setRedshiftEndpoint("dswb-natgeo")
setTable("beacons_4744");
# Out:
# Redshift endpoint set: 2017-06-22T14:38:24

# %%
bc = getBeaconCount();
all = getBeaconsFirstAndLast();
bcType = getBeaconCountByType();
# Out:
# WARNING: This function will soon be deprecated.  Please look into using the following function instead: getBeaconCount

# %%
methods(getBeaconCount)
# Out:
# fatal: Not a git repository (or any of the parent directories): .git
# # 3 methods for generic function "getBeaconCount":
# getBeaconCount() at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBAnalysis/src/DSWBAnalysis.jl:610
# getBeaconCount(startTime::DateTime) at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBAnalysis/src/DSWBAnalysis.jl:610
# getBeaconCount(startTime::DateTime, endTime::DateTime) at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBAnalysis/src/DSWBAnalysis.jl:610

# %%
beautifyDF(names!(bc[:,:],[symbol("Beacon Count")]))
beautifyDF(all)
beautifyDF(names!(bcType[:,:],[symbol("Beacon Type"),symbol("Beacon Count")]))
# Out:
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Beacon Count</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"text-align:right;\">156,297,906</td></tr>\n    \n    \n    </tbody>\n")
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">First Beacon</th> <th class=\"cell-2\" style=\"\">Last Beacon</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">2017-03-14T04:10:41</td> <td class=\"cell-2\" style=\"\">2017-06-21T23:59:59</td></tr>\n    \n    \n    </tbody>\n")
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Beacon Count</th> <th class=\"cell-2\" style=\"\">Beacon Type</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">page view</td> <td class=\"cell-2\" style=\"text-align:right;\">156,156,620</td></tr>\n<tr><td class=\"cell-1\" style=\"\">unload</td> <td class=\"cell-2\" style=\"text-align:right;\">82,765,292</td></tr>\n    \n    <tr><td class=\"cell-1\" style=\"\">error</td> <td class=\"cell-2\" style=\"text-align:right;\">143,732</td></tr>\n    </tbody>\n")

# %%
query("""\
select * from beacons_4744 where page_group = 'News Article' limit 3
""")
# Out:
# 3x246 DataFrames.DataFrame
# │ Row │ compression_types │ custom_metrics_0 │ custom_metrics_1 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ 1                │ NA               │
# │ 2   │ NA                │ 1                │ NA               │
# │ 3   │ NA                │ 1                │ NA               │
#
# │ Row │ custom_metrics_2 │ custom_metrics_3 │ custom_metrics_4 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ NA               │
# │ 2   │ NA               │ NA               │ NA               │
# │ 3   │ NA               │ NA               │ NA               │
#
# │ Row │ custom_metrics_5 │ custom_metrics_6 │ custom_metrics_7 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ NA               │
# │ 2   │ NA               │ NA               │ NA               │
# │ 3   │ NA               │ NA               │ NA               │
#
# │ Row │ custom_metrics_8 │ custom_metrics_9 │ domain                   │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ "nationalgeographic.com" │
# │ 2   │ NA               │ NA               │ "nationalgeographic.com" │
# │ 3   │ NA               │ NA               │ "nationalgeographic.com" │
#
# │ Row │ geo_cc │ geo_city       │ geo_lat  │ geo_lon │ geo_netspeed │
# ┝━━━━━┿━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━┿━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ "MA"   │ NA             │ 32.0     │ -5.0    │ NA           │
# │ 2   │ "ZA"   │ "Johannesburg" │ -26.2052 │ 28.0498 │ "Cellular"   │
# │ 3   │ "ZA"   │ NA             │ -29.0    │ 24.0    │ NA           │
#
# │ Row │ geo_org              │ geo_postalcode │ geo_rg │ http_method │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━┿━━━━━━━━━━━━━┥
# │ 1   │ "Inwi Mobile"        │ NA             │ NA     │ "POST"      │
# │ 2   │ "Vodacom"            │ "2041"         │ "06"   │ "GET"       │
# │ 3   │ "Internet Solutions" │ NA             │ NA     │ "GET"       │
#
# │ Row │ http_referrer                                                                                                                                                                                                   │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "http://news.nationalgeographic.com/2017/03/great-white-shark-numbers-rising-cape-cod/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170313news-trendingcapecod&utm_campaign=Content&sf61982804=1" │
# │ 2   │ "null"                                                                                                                                                                                                          │
# │ 3   │ "null"                                                                                                                                                                                                          │
#
# │ Row │ http_version │ key                             │
# ┝━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "HTTP/1.1"   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │
# │ 2   │ "HTTP/1.1"   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │
# │ 3   │ "HTTP/1.1"   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │
#
# │ Row │ mobile_connection_type │ page_group     │ params_bat_lvl │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                     │ "News Article" │ 1.0            │
# │ 2   │ NA                     │ "News Article" │ NA             │
# │ 3   │ NA                     │ "News Article" │ NA             │
#
# │ Row │ params_cmet_mpulseid │ params_cpu_cnc │ params_custom0_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                   │ 2              │ NA                │
# │ 2   │ NA                   │ NA             │ NA                │
# │ 3   │ NA                   │ NA             │ NA                │
#
# │ Row │ params_custom1_st │ params_custom2_st │ params_custom3_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ 6967              │ 472               │
# │ 2   │ NA                │ NA                │ NA                │
# │ 3   │ NA                │ NA                │ NA                │
#
# │ Row │ params_custom4_st │ params_custom5_st │ params_custom6_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 4813              │ 2113              │ 2111              │
# │ 2   │ NA                │ NA                │ NA                │
# │ 3   │ NA                │ NA                │ NA                │
#
# │ Row │ params_custom7_st │ params_custom8_st │ params_custom9_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 4620              │ 2826              │ NA                │
# │ 2   │ NA                │ NA                │ NA                │
# │ 3   │ NA                │ NA                │ NA                │
#
# │ Row │ params_dom_doms │ params_dom_img │ params_dom_ln │ params_dom_res │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 24              │ 4              │ 840           │ 53             │
# │ 2   │ NA              │ 5              │ 1002          │ NA             │
# │ 3   │ NA              │ 6              │ 1120          │ NA             │
#
# │ Row │ params_dom_res_slowest │ params_dom_script │ params_dom_sz │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                     │ 61                │ 183993        │
# │ 2   │ NA                     │ 60                │ 202235        │
# │ 3   │ NA                     │ 58                │ 230176        │
#
# │ Row │ params_errors │ params_h_t    │ params_if │ params_mem_total │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA            │ 1489464673334 │ ""        │ NA               │
# │ 2   │ NA            │ 1489464522027 │ ""        │ NA               │
# │ 3   │ NA            │ 1489464908675 │ ""        │ NA               │
#
# │ Row │ params_mem_used │ params_mob_bw │ params_mob_mt │ params_nt_con_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA              │ NA            │ NA            │ 1.48946e12        │
# │ 2   │ NA              │ NA            │ NA            │ 1.48946e12        │
# │ 3   │ NA              │ NA            │ NA            │ 1.48946e12        │
#
# │ Row │ params_nt_con_st │ params_nt_dns_end │ params_nt_dns_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
# │ 2   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
# │ 3   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
#
# │ Row │ params_nt_domcomp │ params_nt_domcontloaded_e │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12        │ 1.48946e12                │
# │ 2   │ 1.48946e12        │ 1.48946e12                │
# │ 3   │ 1.48946e12        │ 1.48946e12                │
#
# │ Row │ params_nt_domcontloaded_st │ params_nt_domint │ params_nt_domloading │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12                 │ 1.48946e12       │ 1.48946e12           │
# │ 2   │ 1.48946e12                 │ 1.48946e12       │ 1.48946e12           │
# │ 3   │ 1.48946e12                 │ 1.48946e12       │ 1.48946e12           │
#
# │ Row │ params_nt_fet_st │ params_nt_first_paint │ params_nt_load_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12       │ NA                    │ 1.48946e12         │
# │ 2   │ 1.48946e12       │ NA                    │ 1.48946e12         │
# │ 3   │ 1.48946e12       │ NA                    │ 1.48946e12         │
#
# │ Row │ params_nt_load_st │ params_nt_nav_st │ params_nt_nav_type │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12        │ 1.48946e12       │ 0.0                │
# │ 2   │ 1.48946e12        │ 1.48946e12       │ 0.0                │
# │ 3   │ 1.48946e12        │ 1.48946e12       │ 0.0                │
#
# │ Row │ params_nt_red_cnt │ params_nt_red_end │ params_nt_red_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 0.0               │ 0.0               │ 0.0              │
# │ 2   │ 0.0               │ 0.0               │ 0.0              │
# │ 3   │ 0.0               │ 0.0               │ 0.0              │
#
# │ Row │ params_nt_req_st │ params_nt_res_end │ params_nt_res_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
# │ 2   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
# │ 3   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
#
# │ Row │ params_nt_spdy │ params_nt_ssl_st │ params_nt_unload_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA               │ 0.0                  │
# │ 2   │ NA             │ NA               │ 0.0                  │
# │ 3   │ NA             │ NA               │ 0.0                  │
#
# │ Row │ params_nt_unload_st │ params_nu │ params_pgu │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━┥
# │ 1   │ 0.0                 │ NA        │ NA         │
# │ 2   │ 0.0                 │ NA        │ NA         │
# │ 3   │ 0.0                 │ NA        │ NA         │
#
# │ Row │ params_r                                                                              │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "https://web.facebook.com/"                                                           │
# │ 2   │ "http://news.nationalgeographic.com/2017/03/siberia-batagiaka-crater-climate-change/" │
# │ 3   │ "http://m.facebook.com"                                                               │
#
# │ Row │ params_r2 │ params_rt_abld │ params_rt_blstart │ params_rt_bmr_conen │
# ┝━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA        │ NA             │ 1489464672748     │ NA                  │
# │ 2   │ NA        │ NA             │ 1489464694455     │ NA                  │
# │ 3   │ NA        │ NA             │ 1489464907214     │ NA                  │
#
# │ Row │ params_rt_bmr_const │ params_rt_bmr_domen │ params_rt_bmr_domst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_bmr_fetst │ params_rt_bmr_reqst │ params_rt_bmr_resen │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_bmr_resst │ params_rt_bmr_secst │ params_rt_bstart │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ 1489464673426    │
# │ 2   │ NA                  │ NA                  │ 1489464695807    │
# │ 3   │ NA                  │ NA                  │ 1489464908443    │
#
# │ Row │ params_rt_cnf_conen │ params_rt_cnf_const │ params_rt_cnf_domen │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_cnf_domst │ params_rt_cnf_fetst │ params_rt_cnf_reqst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_cnf_resen │ params_rt_cnf_resst │ params_rt_cnf_secst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_cstart │ params_rt_end │ params_rt_ntvu │ params_rt_obo │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ 1489464672257 │ NA             │ NA            │
# │ 2   │ 1489464690254    │ 1489464709292 │ NA             │ NA            │
# │ 3   │ NA               │ 1489464909584 │ NA             │ NA            │
#
# │ Row │ params_rt_quit │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │
# │ 2   │ NA             │
# │ 3   │ NA             │
#
# │ Row │ params_rt_sh                                                              │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "1489464672262=1:0:4276"                                                  │
# │ 2   │ "1489464709302=3:0:45010,1489464526246=2:0:28057,1489464369352=1:0:18058" │
# │ 3   │ "1489464909600=1:0:6454"                                                  │
#
# │ Row │ params_rt_si │ params_rt_sl │
# ┝━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ NA           │ NA           │
# │ 2   │ NA           │ NA           │
# │ 3   │ NA           │ NA           │
#
# │ Row │ params_rt_srst                                                                                        │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "40193534-7954-4c3a-ba59-6c9256830531-1489464672748:0:0:0:1489464667981:1489464669751:1489464672257:" │
# │ 2   │ NA                                                                                                    │
# │ 3   │ "402cb408-76f7-46da-8b7f-7d79b462fc2e-1489464907214:0:0:0:1489464903130:1489464906247:1489464909584:" │
#
# │ Row │ params_rt_start │ params_rt_tstart │ params_rt_tt │ params_scr_bpp │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "navigation"    │ 1489464667981    │ NA           │ "24/24"        │
# │ 2   │ "navigation"    │ 1489464692339    │ NA           │ "32/32"        │
# │ 3   │ "navigation"    │ 1489464903130    │ NA           │ "32/32"        │
#
# │ Row │ params_scr_dpx │ params_scr_mtp │ params_scr_orn        │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA             │ "0/landscape-primary" │
# │ 2   │ 3.0            │ NA             │ NA                    │
# │ 3   │ 2.0            │ NA             │ NA                    │
#
# │ Row │ params_scr_xy │
# ┝━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ "1280x800"    │
# │ 2   │ "414x736"     │
# │ 3   │ "768x1024"    │
#
# │ Row │ params_u                                                                                                                                                                                                                              │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "http://news.nationalgeographic.com/2017/03/great-white-shark-numbers-rising-cape-cod/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170313news-trendingcapecod&utm_campaign=Content&sf61982804=1"                       │
# │ 2   │ "http://news.nationalgeographic.com/news/2015/02/150227-siberia-mystery-holes-craters-pingos-methane-hydrates-science/"                                                                                                               │
# │ 3   │ "http://news.nationalgeographic.com/2017/03/my-climate-action-q-a-aslund-arctic-glacier-greenpeace/?utm_source=Facebook&utm_medium=Social&utm_content=link_fbadv20170313news-peoplevsclimatechange&utm_campaign=Content&sf62051982=1" │
#
# │ Row │ params_v           │ params_vis_lh │ params_vis_lv │ params_vis_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ "1.405.1475087321" │ NA            │ NA            │ "visible"     │
# │ 2   │ "1.405.1475087321" │ NA            │ NA            │ "visible"     │
# │ 3   │ "1.405.1475087321" │ NA            │ NA            │ "visible"     │
#
# │ Row │ proxy_address     │ remote_ip         │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "188.114.110.205" │ "105.67.132.170"  │
# │ 2   │ "197.234.242.55"  │ "41.13.0.86"      │
# │ 3   │ "197.234.242.7"   │ "196.212.184.252" │
#
# │ Row │ session_id                                    │ session_isunload │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "40193534-7954-4c3a-ba59-6c9256830531-omseak" │ "0"              │
# │ 2   │ "85e9fdec-0337-4039-8a4d-91eb10243a9d-omse1r" │ "0"              │
# │ 3   │ "402cb408-76f7-46da-8b7f-7d79b462fc2e-omseh3" │ "0"              │
#
# │ Row │ session_latest  │ session_obopages │ session_pages │ session_start │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ "1489464672257" │ 0                │ 1             │ 1489464667981 │
# │ 2   │ "1489464709292" │ 0                │ 3             │ 1489464351287 │
# │ 3   │ "1489464909584" │ 0                │ 1             │ 1489464903130 │
#
# │ Row │ session_totalloadtime │ spdy │ ssl │ timers_before_dns │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━┿━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 4276                  │ NA   │ NA  │ 1718              │
# │ 2   │ 45010                 │ NA   │ NA  │ 4                 │
# │ 3   │ 6454                  │ NA   │ NA  │ 538               │
#
# │ Row │ timers_boomerang │ timers_boomr_fb │ timers_boomr_lat │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 42               │ 5445            │ 678              │
# │ 2   │ 76               │ 3468            │ 1352             │
# │ 3   │ 59               │ 5313            │ 1229             │
#
# │ Row │ timers_boomr_ld │ timers_boomr_to_end │ timers_custom0 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 4767            │ -491                │ 7836           │
# │ 2   │ 2116            │ 14837               │ 19141          │
# │ 3   │ 4084            │ 2370                │ 8542           │
#
# │ Row │ timers_custom1 │ timers_custom2 │ timers_custom3 │ timers_custom4 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ 663            │ 413            │ 3              │
# │ 2   │ NA             │ NA             │ NA             │ NA             │
# │ 3   │ NA             │ NA             │ NA             │ NA             │
#
# │ Row │ timers_custom5 │ timers_custom6 │ timers_custom7 │ timers_custom8 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 161            │ 91             │ 211            │ 684            │
# │ 2   │ NA             │ NA             │ NA             │ NA             │
# │ 3   │ NA             │ NA             │ NA             │ NA             │
#
# │ Row │ timers_custom9 │ timers_dns │ timers_domload │ timers_domready │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ 78         │ 2084           │ 7836            │
# │ 2   │ NA             │ 17         │ 1667           │ 19141           │
# │ 3   │ NA             │ 192        │ 1190           │ 8542            │
#
# │ Row │ timers_fb_to_boomr │ timers_loaded │ timers_missing │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 2684               │ 7951          │ NA             │
# │ 2   │ 1654               │ 19385         │ NA             │
# │ 3   │ 2935               │ 8678          │ NA             │
#
# │ Row │ timers_navst_to_boomr │ timers_renderstart │ timers_ssl │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┥
# │ 1   │ 4767                  │ NA                 │ NA         │
# │ 2   │ 2116                  │ NA                 │ NA         │
# │ 3   │ 4084                  │ NA                 │ NA         │
#
# │ Row │ timers_t_configfb │ timers_t_configjs │ timers_t_domloaded │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 4048              │ 353               │ NA                 │
# │ 2   │ 3344              │ 911               │ NA                 │
# │ 3   │ 3275              │ 1103              │ NA                 │
#
# │ Row │ timers_t_done │ timers_t_load │ timers_t_page │ timers_t_postrender │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 4276          │ NA            │ 2193          │ NA                  │
# │ 2   │ 16953         │ NA            │ 16491         │ NA                  │
# │ 3   │ 6454          │ NA            │ 5305          │ NA                  │
#
# │ Row │ timers_t_prerender │ timers_t_resp │ timers_tcp │ timestamp     │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ 2083          │ 0          │ 1489464676766 │
# │ 2   │ NA                 │ 462           │ 51         │ 1489464712326 │
# │ 3   │ NA                 │ 1149          │ 197        │ 1489464912239 │
#
# │ Row │ url                                   │ user_agent_family │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "http://news.nationalgeographic.com/" │ "Firefox"         │
# │ 2   │ "http://news.nationalgeographic.com/" │ "Facebook"        │
# │ 3   │ "http://news.nationalgeographic.com/" │ "Facebook"        │
#
# │ Row │ user_agent_major │ user_agent_minor │ user_agent_mobile │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 48               │ 0                │ "0"               │
# │ 2   │ 83               │ 0                │ "1"               │
# │ 3   │ 66               │ 0                │ "0"               │
#
# │ Row │ user_agent_model │ user_agent_os │ user_agent_osversion │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ "Mac OS X"    │ "10"                 │
# │ 2   │ "iPhone"         │ "iOS"         │ "10"                 │
# │ 3   │ NA               │ "iOS"         │ "10"                 │
#
# │ Row │ user_agent_raw                                                                                                                                                                                                                                                       │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv:48.0) Gecko/20100101 Firefox/48.0"                                                                                                                                                                                  │
# │ 2   │ "Mozilla/5.0 (iPhone; CPU iPhone OS 10_2_1 like Mac OS X) AppleWebKit/602.4.6 (KHTML, like Gecko) Mobile/14D27 [FBAN/FBIOS;FBAV/83.0.0.38.70;FBBV/51754296;FBDV/iPhone7,1;FBMD/iPhone;FBSN/iOS;FBSV/10.2.1;FBSS/3;FBCR/Vodacom;FBID/phone;FBLC/en_US;FBOP/5;FBRV/0]" │
# │ 3   │ "Mozilla/5.0 (iPad; CPU OS 10_0_2 like Mac OS X) AppleWebKit/602.1.50 (KHTML, like Gecko) Mobile/14A456 [FBAN/FBIOS;FBAV/66.0.0.42.70;FBBV/40764466;FBRV/0;FBDV/iPad4,5;FBMD/iPad;FBSN/iOS;FBSV/10.0.2;FBSS/2;FBCR/Vodacom;FBID/tablet;FBLC/en_US;FBOP/5]"           │
#
# │ Row │ warnings                    │ beacon_type │ site_version │ ab_test │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━┥
# │ 1   │ NA                          │ "page view" │ NA           │ NA      │
# │ 2   │ "[\"referrer-url-mismatch\"]" │ "page view" │ NA           │ NA      │
# │ 3   │ "[\"referrer-url-mismatch\"]" │ "page view" │ NA           │ NA      │
#
# │ Row │ ipv6 │ user_agent_manufacturer │ user_agent_device_type │
# ┝━━━━━┿━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA   │ NA                      │ "Desktop"              │
# │ 2   │ NA   │ "Apple"                 │ "Mobile"               │
# │ 3   │ NA   │ NA                      │ NA                     │
#
# │ Row │ user_agent_isp │ geo_isp              │ bandwidth_kbps │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ "Inwi Mobile"        │ NA             │
# │ 2   │ NA             │ "Vodacom"            │ NA             │
# │ 3   │ NA             │ "Internet Solutions" │ NA             │
#
# │ Row │ bandwidth_error_pc │ bandwidth_block │ headers_cf_visitor │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA              │ NA                 │
# │ 2   │ NA                 │ NA              │ NA                 │
# │ 3   │ NA                 │ NA              │ NA                 │
#
# │ Row │ headers_cf_ray │ headers_cf_connecting_ip │ headers_x_forwarded_for │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA                       │ NA                      │
# │ 2   │ NA             │ NA                       │ NA                      │
# │ 3   │ NA             │ NA                       │ NA                      │
#
# │ Row │ headers_x_forwarded_proto │ headers_connection │ headers_host │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ NA                        │ NA                 │ NA           │
# │ 2   │ NA                        │ NA                 │ NA           │
# │ 3   │ NA                        │ NA                 │ NA           │
#
# │ Row │ headers_accept_encoding │ headers_accept_language │ headers_accept │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                      │ NA                      │ NA             │
# │ 2   │ NA                      │ NA                      │ NA             │
# │ 3   │ NA                      │ NA                      │ NA             │
#
# │ Row │ headers_content_length │ headers_various │ params_dom_img_ext │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                     │ NA              │ NA                 │
# │ 2   │ NA                     │ NA              │ NA                 │
# │ 3   │ NA                     │ NA              │ NA                 │
#
# │ Row │ params_dom_script_ext │ params_ua_plt │ params_ua_vnd          │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 31                    │ "MacIntel"    │ ""                     │
# │ 2   │ 31                    │ "iPhone"      │ "Apple Computer, Inc." │
# │ 3   │ 26                    │ "iPad"        │ "Apple Computer, Inc." │
#
# │ Row │ http_errno │ params_http_method │ params_http_hdr │
# ┝━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA         │ NA                 │ NA              │
# │ 2   │ NA         │ NA                 │ NA              │
# │ 3   │ NA         │ NA                 │ NA              │
#
# │ Row │ params_http_initiator │ params_h_cr │ params_xhr_sync │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                    │ NA          │ NA              │
# │ 2   │ NA                    │ NA          │ NA              │
# │ 3   │ NA                    │ NA          │ NA              │
#
# │ Row │ params_rt_subres │ params_bw_time │ params_lat │ params_lat_err │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA             │ NA         │ NA             │
# │ 2   │ NA               │ NA             │ NA         │ NA             │
# │ 3   │ NA               │ NA             │ NA         │ NA             │
#
# │ Row │ params_mob_ct │ cdim │ params_nt_cinf │ params_rt_ss │ errors │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━┥
# │ 1   │ NA            │ "[]" │ NA             │ NA           │ NA     │
# │ 2   │ NA            │ "[]" │ NA             │ NA           │ NA     │
# │ 3   │ NA            │ "[]" │ NA             │ NA           │ NA     │
#
# │ Row │ tp_ga_clientid          │ tp_ga_utm_source │ tp_ga_utm_medium │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "1241750353.1479460668" │ "Facebook"       │ "Social"         │
# │ 2   │ "1175798019.1489464357" │ NA               │ NA               │
# │ 3   │ "550198866.1472056500"  │ "Facebook"       │ "Social"         │
#
# │ Row │ tp_ga_utm_term │ tp_ga_utm_content                              │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ "link_fb20170313news-trendingcapecod"          │
# │ 2   │ NA             │ NA                                             │
# │ 3   │ NA             │ "link_fbadv20170313news-peoplevsclimatechange" │
#
# │ Row │ tp_ga_utm_campaign │ tp_aa_aid │ tp_aa_mid │ tp_aa_campaign │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "Content"          │ NA        │ NA        │ NA             │
# │ 2   │ NA                 │ NA        │ NA        │ NA             │
# │ 3   │ "Content"          │ NA        │ NA        │ NA             │
#
# │ Row │ tp_ia_coreid │ tp_ia_mmc_vendor │ tp_ia_mmc_category │
# ┝━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA           │ NA               │ NA                 │
# │ 2   │ NA           │ NA               │ NA                 │
# │ 3   │ NA           │ NA               │ NA                 │
#
# │ Row │ tp_ia_mmc_placement │ tp_ia_mmc_item │ tp_ia_sp_type │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA             │ NA            │
# │ 2   │ NA                  │ NA             │ NA            │
# │ 3   │ NA                  │ NA             │ NA            │
#
# │ Row │ tp_ia_sp_promotion │ tp_ia_sp_link │ tp_ia_re_version │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA            │ NA               │
# │ 2   │ NA                 │ NA            │ NA               │
# │ 3   │ NA                 │ NA            │ NA               │
#
# │ Row │ tp_ia_re_pagearea │ tp_ia_re_link │ tp_aa_purchaseid │ beacon_id │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┥
# │ 1   │ NA                │ NA            │ NA               │ NA        │
# │ 2   │ NA                │ NA            │ NA               │ NA        │
# │ 3   │ NA                │ NA            │ NA               │ NA        │

# %%
query("""\
select * from beacons_4744 where page_group = 'News Article' and beacon_type = 'page view' limit 3
""")
# Out:
# 3x246 DataFrames.DataFrame
# │ Row │ compression_types │ custom_metrics_0 │ custom_metrics_1 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ 1                │ NA               │
# │ 2   │ NA                │ 1                │ NA               │
# │ 3   │ NA                │ 1                │ NA               │
#
# │ Row │ custom_metrics_2 │ custom_metrics_3 │ custom_metrics_4 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ NA               │
# │ 2   │ NA               │ NA               │ NA               │
# │ 3   │ NA               │ NA               │ NA               │
#
# │ Row │ custom_metrics_5 │ custom_metrics_6 │ custom_metrics_7 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ NA               │
# │ 2   │ NA               │ NA               │ NA               │
# │ 3   │ NA               │ NA               │ NA               │
#
# │ Row │ custom_metrics_8 │ custom_metrics_9 │ domain                   │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ "nationalgeographic.com" │
# │ 2   │ NA               │ NA               │ "nationalgeographic.com" │
# │ 3   │ NA               │ NA               │ "nationalgeographic.com" │
#
# │ Row │ geo_cc │ geo_city   │ geo_lat │ geo_lon │ geo_netspeed │
# ┝━━━━━┿━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━┿━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ "RS"   │ "Leskovac" │ 42.9981 │ 21.9461 │ "Cable/DSL"  │
# │ 2   │ "IL"   │ NA         │ 31.5    │ 34.75   │ "Cellular"   │
# │ 3   │ "RO"   │ NA         │ 46.0    │ 25.0    │ "Cable/DSL"  │
#
# │ Row │ geo_org                                          │ geo_postalcode │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "Serbia BroadBand-Srpske Kablovske mreze d.o.o." │ NA             │
# │ 2   │ "HOT Mobile Ltd."                                │ NA             │
# │ 3   │ "RCS & RDS Business"                             │ NA             │
#
# │ Row │ geo_rg │ http_method │
# ┝━━━━━┿━━━━━━━━┿━━━━━━━━━━━━━┥
# │ 1   │ "00"   │ "POST"      │
# │ 2   │ NA     │ "POST"      │
# │ 3   │ NA     │ "POST"      │
#
# │ Row │ http_referrer                                                                                                                                                                                                                     │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "http://news.nationalgeographic.com/2017/03/marbled-cat-china-endangered-video/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170313news-marbledcat&utm_campaign=Content&sf62109970=1"                               │
# │ 2   │ "http://news.nationalgeographic.com/2016/03/160312-daylight-savings-sleep-cultures-pictures/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170312news-sleepgallery2&utm_campaign=Content&sf61677588=1"               │
# │ 3   │ "http://news.nationalgeographic.com/2017/03/great-white-shark-numbers-rising-cape-cod/?utm_source=Facebook&utm_campaign=NEWS&utm_medium=Social&utm_content=link_fbwd20170313NEWSgreatwhitesharknumbersrisingcapecod&sf62034212=1" │
#
# │ Row │ http_version │ key                             │
# ┝━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "HTTP/1.1"   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │
# │ 2   │ "HTTP/1.1"   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │
# │ 3   │ "HTTP/1.1"   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │
#
# │ Row │ mobile_connection_type │ page_group     │ params_bat_lvl │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "WiFi"                 │ "News Article" │ 0.67           │
# │ 2   │ NA                     │ "News Article" │ 0.42           │
# │ 3   │ NA                     │ "News Article" │ NA             │
#
# │ Row │ params_cmet_mpulseid │ params_cpu_cnc │ params_custom0_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                   │ 2              │ NA                │
# │ 2   │ NA                   │ 4              │ NA                │
# │ 3   │ NA                   │ NA             │ NA                │
#
# │ Row │ params_custom1_st │ params_custom2_st │ params_custom3_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ 22974             │ 2111              │
# │ 2   │ NA                │ 16723             │ 624               │
# │ 3   │ NA                │ 15990             │ 363               │
#
# │ Row │ params_custom4_st │ params_custom5_st │ params_custom6_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 20191             │ 957               │ 930               │
# │ 2   │ 21793             │ 7433              │ 7432              │
# │ 3   │ 14022             │ 1657              │ 1658              │
#
# │ Row │ params_custom7_st │ params_custom8_st │ params_custom9_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 18752             │ 4102              │ NA                │
# │ 2   │ 15453             │ 9724              │ NA                │
# │ 3   │ 16432             │ 3790              │ NA                │
#
# │ Row │ params_dom_doms │ params_dom_img │ params_dom_ln │ params_dom_res │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 32              │ 5              │ 1039          │ 65             │
# │ 2   │ 32              │ 4              │ 958           │ 70             │
# │ 3   │ 31              │ 4              │ 854           │ 63             │
#
# │ Row │ params_dom_res_slowest │ params_dom_script │ params_dom_sz │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                     │ 62                │ 202576        │
# │ 2   │ NA                     │ 60                │ 200693        │
# │ 3   │ NA                     │ 60                │ 181322        │
#
# │ Row │ params_errors │ params_h_t    │ params_if │ params_mem_total │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA            │ 1489464620986 │ ""        │ 10000000         │
# │ 2   │ NA            │ 1489464630602 │ ""        │ 131000000        │
# │ 3   │ NA            │ 1489464669271 │ ""        │ 13400000         │
#
# │ Row │ params_mem_used │ params_mob_bw │ params_mob_mt │ params_nt_con_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 10000000        │ ""            │ NA            │ 1.48946e12        │
# │ 2   │ 47400000        │ ""            │ NA            │ 1.48946e12        │
# │ 3   │ 10000000        │ NA            │ NA            │ 1.48946e12        │
#
# │ Row │ params_nt_con_st │ params_nt_dns_end │ params_nt_dns_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
# │ 2   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
# │ 3   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
#
# │ Row │ params_nt_domcomp │ params_nt_domcontloaded_e │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12        │ 1.48946e12                │
# │ 2   │ 1.48946e12        │ 1.48946e12                │
# │ 3   │ 1.48946e12        │ 1.48946e12                │
#
# │ Row │ params_nt_domcontloaded_st │ params_nt_domint │ params_nt_domloading │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12                 │ 1.48946e12       │ 1.48946e12           │
# │ 2   │ 1.48946e12                 │ 1.48946e12       │ 1.48946e12           │
# │ 3   │ 1.48946e12                 │ 1.48946e12       │ 1.48946e12           │
#
# │ Row │ params_nt_fet_st │ params_nt_first_paint │ params_nt_load_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12       │ "1489464615206"       │ 1.48946e12         │
# │ 2   │ 1.48946e12       │ "1489464620176"       │ 1.48946e12         │
# │ 3   │ 1.48946e12       │ NA                    │ 1.48946e12         │
#
# │ Row │ params_nt_load_st │ params_nt_nav_st │ params_nt_nav_type │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12        │ 1.48946e12       │ 0.0                │
# │ 2   │ 1.48946e12        │ 1.48946e12       │ 0.0                │
# │ 3   │ 1.48946e12        │ 1.48946e12       │ 0.0                │
#
# │ Row │ params_nt_red_cnt │ params_nt_red_end │ params_nt_red_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 0.0               │ 0.0               │ 0.0              │
# │ 2   │ 0.0               │ 0.0               │ 0.0              │
# │ 3   │ 0.0               │ 0.0               │ 0.0              │
#
# │ Row │ params_nt_req_st │ params_nt_res_end │ params_nt_res_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
# │ 2   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
# │ 3   │ 1.48946e12       │ 1.48946e12        │ 1.48946e12       │
#
# │ Row │ params_nt_spdy │ params_nt_ssl_st │ params_nt_unload_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 0.0            │ NA               │ 0.0                  │
# │ 2   │ 0.0            │ NA               │ 0.0                  │
# │ 3   │ NA             │ NA               │ 0.0                  │
#
# │ Row │ params_nt_unload_st │ params_nu │ params_pgu │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━┥
# │ 1   │ 0.0                 │ NA        │ NA         │
# │ 2   │ 0.0                 │ NA        │ NA         │
# │ 3   │ 0.0                 │ NA        │ NA         │
#
# │ Row │ params_r                  │ params_r2 │ params_rt_abld │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                        │ NA        │ NA             │
# │ 2   │ "https://m.facebook.com/" │ NA        │ NA             │
# │ 3   │ "http://m.facebook.com/"  │ NA        │ NA             │
#
# │ Row │ params_rt_blstart │ params_rt_bmr_conen │ params_rt_bmr_const │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 1489464617946     │ NA                  │ NA                  │
# │ 2   │ 1489464628132     │ NA                  │ NA                  │
# │ 3   │ 1489464668164     │ NA                  │ NA                  │
#
# │ Row │ params_rt_bmr_domen │ params_rt_bmr_domst │ params_rt_bmr_fetst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_bmr_reqst │ params_rt_bmr_resen │ params_rt_bmr_resst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_bmr_secst │ params_rt_bstart │ params_rt_cnf_conen │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ 1489464620245    │ NA                  │
# │ 2   │ NA                  │ 1489464629416    │ NA                  │
# │ 3   │ NA                  │ 1489464668989    │ NA                  │
#
# │ Row │ params_rt_cnf_const │ params_rt_cnf_domen │ params_rt_cnf_domst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_cnf_fetst │ params_rt_cnf_reqst │ params_rt_cnf_resen │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_cnf_resst │ params_rt_cnf_secst │ params_rt_cstart │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA               │
# │ 2   │ NA                  │ NA                  │ NA               │
# │ 3   │ NA                  │ NA                  │ NA               │
#
# │ Row │ params_rt_end │ params_rt_ntvu │ params_rt_obo │ params_rt_quit │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 1489464641581 │ NA             │ NA            │ NA             │
# │ 2   │ 1489464636457 │ NA             │ NA            │ NA             │
# │ 3   │ 1489464671618 │ NA             │ NA            │ NA             │
#
# │ Row │ params_rt_sh              │ params_rt_si │ params_rt_sl │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ "1489464641623=1:0:30634" │ NA           │ NA           │
# │ 2   │ "1489464636486=1:0:26147" │ NA           │ NA           │
# │ 3   │ "1489464671650=1:0:12672" │ NA           │ NA           │
#
# │ Row │ params_rt_srst                                                                                │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "86bda9d3-ea3e-41f1-90d6-d6ab7b0071e1-undefined:0:0:0:1489464610947:undefined:1489464641581:" │
# │ 2   │ "c351a18f-00a5-4e92-be91-7043175aa7e2-undefined:0:0:0:1489464610310:undefined:1489464636457:" │
# │ 3   │ "c5f27802-56b4-42ac-99f8-aafd74a5e099-undefined:0:0:0:1489464658946:undefined:1489464671618:" │
#
# │ Row │ params_rt_start │ params_rt_tstart │ params_rt_tt │ params_scr_bpp │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "navigation"    │ 1489464610947    │ NA           │ "32/32"        │
# │ 2   │ "navigation"    │ 1489464610310    │ NA           │ "32/32"        │
# │ 3   │ "navigation"    │ 1489464658946    │ NA           │ "32/32"        │
#
# │ Row │ params_scr_dpx │ params_scr_mtp │ params_scr_orn       │ params_scr_xy │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ 1.5            │ 2              │ "0/portrait-primary" │ "320x570"     │
# │ 2   │ 3.0            │ 5              │ "0/portrait-primary" │ "360x640"     │
# │ 3   │ 1.5            │ NA             │ NA                   │ "320x570"     │
#
# │ Row │ params_u                                                                                                                                                                                                                          │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "http://news.nationalgeographic.com/2017/03/marbled-cat-china-endangered-video/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170313news-marbledcat&utm_campaign=Content&sf62109970=1"                               │
# │ 2   │ "http://news.nationalgeographic.com/2016/03/160312-daylight-savings-sleep-cultures-pictures/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170312news-sleepgallery2&utm_campaign=Content&sf61677588=1"               │
# │ 3   │ "http://news.nationalgeographic.com/2017/03/great-white-shark-numbers-rising-cape-cod/?utm_source=Facebook&utm_campaign=NEWS&utm_medium=Social&utm_content=link_fbwd20170313NEWSgreatwhitesharknumbersrisingcapecod&sf62034212=1" │
#
# │ Row │ params_v           │ params_vis_lh │ params_vis_lv │ params_vis_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ "1.405.1475087321" │ NA            │ NA            │ "visible"     │
# │ 2   │ "1.405.1475087321" │ NA            │ NA            │ "visible"     │
# │ 3   │ "1.405.1475087321" │ NA            │ NA            │ "visible"     │
#
# │ Row │ proxy_address     │ remote_ip        │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "162.158.210.79"  │ "178.149.75.14"  │
# │ 2   │ "162.158.91.218"  │ "80.246.133.217" │
# │ 3   │ "162.158.111.238" │ "82.79.114.176"  │
#
# │ Row │ session_id                                    │ session_isunload │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "86bda9d3-ea3e-41f1-90d6-d6ab7b0071e1-omse8z" │ "0"              │
# │ 2   │ "c351a18f-00a5-4e92-be91-7043175aa7e2-omse8y" │ "0"              │
# │ 3   │ "c5f27802-56b4-42ac-99f8-aafd74a5e099-omseab" │ "0"              │
#
# │ Row │ session_latest  │ session_obopages │ session_pages │ session_start │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ "1489464641581" │ 0                │ 1             │ 1489464610947 │
# │ 2   │ "1489464636457" │ 0                │ 1             │ 1489464610310 │
# │ 3   │ "1489464671618" │ 0                │ 1             │ 1489464658946 │
#
# │ Row │ session_totalloadtime │ spdy │ ssl │ timers_before_dns │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━┿━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 30634                 │ NA   │ NA  │ 521               │
# │ 2   │ 26147                 │ NA   │ NA  │ 7144              │
# │ 3   │ 12672                 │ NA   │ NA  │ 1344              │
#
# │ Row │ timers_boomerang │ timers_boomr_fb │ timers_boomr_lat │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 220              │ 9298            │ 2299             │
# │ 2   │ 256              │ 19106           │ 1284             │
# │ 3   │ 132              │ 10043           │ 825              │
#
# │ Row │ timers_boomr_ld │ timers_boomr_to_end │ timers_custom0 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 6999            │ 23635               │ 41579          │
# │ 2   │ 17822           │ 8325                │ 37529          │
# │ 3   │ 9218            │ 3454                │ 23382          │
#
# │ Row │ timers_custom1 │ timers_custom2 │ timers_custom3 │ timers_custom4 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ 790            │ 1845           │ 873            │
# │ 2   │ NA             │ 653            │ 223            │ 226            │
# │ 3   │ NA             │ 2341           │ 856            │ 700            │
#
# │ Row │ timers_custom5 │ timers_custom6 │ timers_custom7 │ timers_custom8 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 941            │ 1932           │ 391            │ 1243           │
# │ 2   │ 232            │ 134            │ 391            │ 1539           │
# │ 3   │ 847            │ 969            │ 721            │ 4780           │
#
# │ Row │ timers_custom9 │ timers_dns │ timers_domload │ timers_domready │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ 178        │ 908            │ 41579           │
# │ 2   │ NA             │ 38         │ 7405           │ 37529           │
# │ 3   │ NA             │ 53         │ 1627           │ 23382           │
#
# │ Row │ timers_fb_to_boomr │ timers_loaded │ timers_missing │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 6139               │ 42183         │ NA             │
# │ 2   │ 10477              │ 37786         │ NA             │
# │ 3   │ 7644               │ 23688         │ NA             │
#
# │ Row │ timers_navst_to_boomr │ timers_renderstart │ timers_ssl │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┥
# │ 1   │ 6999                  │ 4259               │ NA         │
# │ 2   │ 17822                 │ 9866               │ NA         │
# │ 3   │ 9218                  │ NA                 │ NA         │
#
# │ Row │ timers_t_configfb │ timers_t_configjs │ timers_t_domloaded │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 404               │ 470               │ NA                 │
# │ 2   │ 14220             │ 2488              │ NA                 │
# │ 3   │ 6442              │ -4639             │ NA                 │
#
# │ Row │ timers_t_done │ timers_t_load │ timers_t_page │ timers_t_postrender │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 30634         │ NA            │ 29774         │ NA                  │
# │ 2   │ 26147         │ NA            │ 18802         │ NA                  │
# │ 3   │ 12672         │ NA            │ 11098         │ NA                  │
#
# │ Row │ timers_t_prerender │ timers_t_resp │ timers_tcp │ timestamp     │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ 860           │ 119        │ 1489464660545 │
# │ 2   │ NA                 │ 7345          │ 30         │ 1489464674036 │
# │ 3   │ NA                 │ 1574          │ 48         │ 1489464684903 │
#
# │ Row │ url                                   │ user_agent_family │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "http://news.nationalgeographic.com/" │ "Chrome Mobile"   │
# │ 2   │ "http://news.nationalgeographic.com/" │ "Chrome Mobile"   │
# │ 3   │ "http://news.nationalgeographic.com/" │ "Facebook"        │
#
# │ Row │ user_agent_major │ user_agent_minor │ user_agent_mobile │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 45               │ 0                │ "0"               │
# │ 2   │ 56               │ 0                │ "1"               │
# │ 3   │ 100              │ 0                │ "1"               │
#
# │ Row │ user_agent_model      │ user_agent_os │ user_agent_osversion │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "Sony Xperia M C1905" │ "Android OS"  │ "4.3"                │
# │ 2   │ NA                    │ "Android OS"  │ "5"                  │
# │ 3   │ NA                    │ "Android OS"  │ "4"                  │
#
# │ Row │ user_agent_raw                                                                                                                                                                           │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "Mozilla/5.0 (Linux; Android 4.3; C1905 Build/15.4.A.1.9) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.84 Mobile Safari/537.36"                                               │
# │ 2   │ "Mozilla/5.0 (Linux; Android 5.0.1; GT-I9505 Build/LRX22C) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Mobile Safari/537.36"                                              │
# │ 3   │ "Mozilla/5.0 (Linux; Android 4.4.2; Lenovo A328 Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/30.0.0.0 Mobile Safari/537.36 [FB_IAB/FB4A;FBAV/100.0.0.20.70;]" │
#
# │ Row │ warnings │ beacon_type │ site_version │ ab_test │ ipv6 │
# ┝━━━━━┿━━━━━━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━┿━━━━━━┥
# │ 1   │ NA       │ "page view" │ NA           │ NA      │ NA   │
# │ 2   │ NA       │ "page view" │ NA           │ NA      │ NA   │
# │ 3   │ NA       │ "page view" │ NA           │ NA      │ NA   │
#
# │ Row │ user_agent_manufacturer │ user_agent_device_type │ user_agent_isp │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "Sony"                  │ "Mobile"               │ NA             │
# │ 2   │ "Samsung"               │ "Mobile"               │ NA             │
# │ 3   │ "Lenovo"                │ "Mobile"               │ NA             │
#
# │ Row │ geo_isp                                          │ bandwidth_kbps │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "Serbia BroadBand-Srpske Kablovske mreze d.o.o." │ NA             │
# │ 2   │ "HOT Mobile Ltd."                                │ NA             │
# │ 3   │ "RCS & RDS"                                      │ NA             │
#
# │ Row │ bandwidth_error_pc │ bandwidth_block │ headers_cf_visitor │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA              │ NA                 │
# │ 2   │ NA                 │ NA              │ NA                 │
# │ 3   │ NA                 │ NA              │ NA                 │
#
# │ Row │ headers_cf_ray │ headers_cf_connecting_ip │ headers_x_forwarded_for │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA                       │ NA                      │
# │ 2   │ NA             │ NA                       │ NA                      │
# │ 3   │ NA             │ NA                       │ NA                      │
#
# │ Row │ headers_x_forwarded_proto │ headers_connection │ headers_host │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ NA                        │ NA                 │ NA           │
# │ 2   │ NA                        │ NA                 │ NA           │
# │ 3   │ NA                        │ NA                 │ NA           │
#
# │ Row │ headers_accept_encoding │ headers_accept_language │ headers_accept │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                      │ NA                      │ NA             │
# │ 2   │ NA                      │ NA                      │ NA             │
# │ 3   │ NA                      │ NA                      │ NA             │
#
# │ Row │ headers_content_length │ headers_various │ params_dom_img_ext │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                     │ NA              │ 4                  │
# │ 2   │ NA                     │ NA              │ NA                 │
# │ 3   │ NA                     │ NA              │ NA                 │
#
# │ Row │ params_dom_script_ext │ params_ua_plt  │ params_ua_vnd │ http_errno │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┥
# │ 1   │ 33                    │ "Linux armv7l" │ "Google Inc." │ NA         │
# │ 2   │ 31                    │ "Linux armv7l" │ "Google Inc." │ NA         │
# │ 3   │ 30                    │ "Linux armv7l" │ "Google Inc." │ NA         │
#
# │ Row │ params_http_method │ params_http_hdr │ params_http_initiator │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA              │ NA                    │
# │ 2   │ NA                 │ NA              │ NA                    │
# │ 3   │ NA                 │ NA              │ NA                    │
#
# │ Row │ params_h_cr │ params_xhr_sync │ params_rt_subres │ params_bw_time │
# ┝━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA          │ NA              │ NA               │ NA             │
# │ 2   │ NA          │ NA              │ NA               │ NA             │
# │ 3   │ NA          │ NA              │ NA               │ NA             │
#
# │ Row │ params_lat │ params_lat_err │ params_mob_ct │ cdim │ params_nt_cinf │
# ┝━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA         │ NA             │ NA            │ "[]" │ "http/1"       │
# │ 2   │ NA         │ NA             │ NA            │ "[]" │ "http/1.1"     │
# │ 3   │ NA         │ NA             │ NA            │ "[]" │ NA             │
#
# │ Row │ params_rt_ss │ errors │ tp_ga_clientid          │ tp_ga_utm_source │
# ┝━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA           │ NA     │ "1274166574.1442654429" │ "Facebook"       │
# │ 2   │ NA           │ NA     │ "617709631.1489464629"  │ "Facebook"       │
# │ 3   │ NA           │ NA     │ "227823506.1489464669"  │ "Facebook"       │
#
# │ Row │ tp_ga_utm_medium │ tp_ga_utm_term │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "Social"         │ NA             │
# │ 2   │ "Social"         │ NA             │
# │ 3   │ "Social"         │ NA             │
#
# │ Row │ tp_ga_utm_content                                          │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "link_fb20170313news-marbledcat"                           │
# │ 2   │ "link_fb20170312news-sleepgallery2"                        │
# │ 3   │ "link_fbwd20170313NEWSgreatwhitesharknumbersrisingcapecod" │
#
# │ Row │ tp_ga_utm_campaign │ tp_aa_aid │ tp_aa_mid │ tp_aa_campaign │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "Content"          │ NA        │ NA        │ NA             │
# │ 2   │ "Content"          │ NA        │ NA        │ NA             │
# │ 3   │ "NEWS"             │ NA        │ NA        │ NA             │
#
# │ Row │ tp_ia_coreid │ tp_ia_mmc_vendor │ tp_ia_mmc_category │
# ┝━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA           │ NA               │ NA                 │
# │ 2   │ NA           │ NA               │ NA                 │
# │ 3   │ NA           │ NA               │ NA                 │
#
# │ Row │ tp_ia_mmc_placement │ tp_ia_mmc_item │ tp_ia_sp_type │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA             │ NA            │
# │ 2   │ NA                  │ NA             │ NA            │
# │ 3   │ NA                  │ NA             │ NA            │
#
# │ Row │ tp_ia_sp_promotion │ tp_ia_sp_link │ tp_ia_re_version │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA            │ NA               │
# │ 2   │ NA                 │ NA            │ NA               │
# │ 3   │ NA                 │ NA            │ NA               │
#
# │ Row │ tp_ia_re_pagearea │ tp_ia_re_link │ tp_aa_purchaseid │ beacon_id │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┥
# │ 1   │ NA                │ NA            │ NA               │ NA        │
# │ 2   │ NA                │ NA            │ NA               │ NA        │
# │ 3   │ NA                │ NA            │ NA               │ NA        │

# %%
query("""\
select * from beacons_4744 where beacon_type = 'error' limit 3
""")
# Out:
# 3x246 DataFrames.DataFrame
# │ Row │ compression_types │ custom_metrics_0 │ custom_metrics_1 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ NA               │ NA               │
# │ 2   │ NA                │ NA               │ NA               │
# │ 3   │ NA                │ NA               │ NA               │
#
# │ Row │ custom_metrics_2 │ custom_metrics_3 │ custom_metrics_4 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ NA               │
# │ 2   │ NA               │ NA               │ NA               │
# │ 3   │ NA               │ NA               │ NA               │
#
# │ Row │ custom_metrics_5 │ custom_metrics_6 │ custom_metrics_7 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ NA               │
# │ 2   │ NA               │ NA               │ NA               │
# │ 3   │ NA               │ NA               │ NA               │
#
# │ Row │ custom_metrics_8 │ custom_metrics_9 │ domain                   │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA               │ "nationalgeographic.com" │
# │ 2   │ NA               │ NA               │ "nationalgeographic.com" │
# │ 3   │ NA               │ NA               │ "nationalgeographic.com" │
#
# │ Row │ geo_cc │ geo_city   │ geo_lat │ geo_lon │ geo_netspeed │
# ┝━━━━━┿━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━┿━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ "TR"   │ "Istanbul" │ 41.0186 │ 28.9647 │ "Cable/DSL"  │
# │ 2   │ "IT"   │ "Rome"     │ 41.9    │ 12.4833 │ "Cable/DSL"  │
# │ 3   │ "IE"   │ NA         │ 53.3478 │ -6.2597 │ "Cellular"   │
#
# │ Row │ geo_org                           │ geo_postalcode │ geo_rg │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━┥
# │ 1   │ "TurkNet Iletisim Hizmetleri A.S" │ NA             │ "34"   │
# │ 2   │ "Fastweb"                         │ "00119"        │ "07"   │
# │ 3   │ "Vodafone Ireland Limited"        │ NA             │ NA     │
#
# │ Row │ http_method │ http_referrer │ http_version │
# ┝━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ "GET"       │ "null"        │ "HTTP/1.1"   │
# │ 2   │ "GET"       │ "null"        │ "HTTP/1.1"   │
# │ 3   │ "GET"       │ "null"        │ "HTTP/1.1"   │
#
# │ Row │ key                             │ mobile_connection_type │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │ NA                     │
# │ 2   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │ NA                     │
# │ 3   │ "M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT" │ NA                     │
#
# │ Row │ page_group        │ params_bat_lvl │ params_cmet_mpulseid │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "(No Page Group)" │ NA             │ NA                   │
# │ 2   │ "(No Page Group)" │ NA             │ NA                   │
# │ 3   │ "(No Page Group)" │ NA             │ NA                   │
#
# │ Row │ params_cpu_cnc │ params_custom0_st │ params_custom1_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA                │ NA                │
# │ 2   │ NA             │ NA                │ NA                │
# │ 3   │ NA             │ NA                │ NA                │
#
# │ Row │ params_custom2_st │ params_custom3_st │ params_custom4_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ NA                │ NA                │
# │ 2   │ NA                │ NA                │ NA                │
# │ 3   │ NA                │ NA                │ NA                │
#
# │ Row │ params_custom5_st │ params_custom6_st │ params_custom7_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ NA                │ NA                │
# │ 2   │ NA                │ NA                │ NA                │
# │ 3   │ NA                │ NA                │ NA                │
#
# │ Row │ params_custom8_st │ params_custom9_st │ params_dom_doms │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ NA                │ NA              │
# │ 2   │ NA                │ NA                │ NA              │
# │ 3   │ NA                │ NA                │ NA              │
#
# │ Row │ params_dom_img │ params_dom_ln │ params_dom_res │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ 5              │ 1058          │ NA             │
# │ 2   │ 8              │ 1132          │ NA             │
# │ 3   │ 5              │ 1280          │ NA             │
#
# │ Row │ params_dom_res_slowest │ params_dom_script │ params_dom_sz │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                     │ 60                │ 221310        │
# │ 2   │ NA                     │ 67                │ 284331        │
# │ 3   │ NA                     │ 63                │ 273717        │
#
# │ Row │ params_errors │ params_h_t    │ params_if │ params_mem_total │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA            │ 1489675983499 │ ""        │ NA               │
# │ 2   │ NA            │ 1489676141383 │ ""        │ 0                │
# │ 3   │ NA            │ 1489676287883 │ ""        │ NA               │
#
# │ Row │ params_mem_used │ params_mob_bw │ params_mob_mt │ params_nt_con_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA              │ NA            │ NA            │ NA                │
# │ 2   │ 0               │ ""            │ NA            │ NA                │
# │ 3   │ NA              │ NA            │ NA            │ NA                │
#
# │ Row │ params_nt_con_st │ params_nt_dns_end │ params_nt_dns_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA                │ NA               │
# │ 2   │ NA               │ NA                │ NA               │
# │ 3   │ NA               │ NA                │ NA               │
#
# │ Row │ params_nt_domcomp │ params_nt_domcontloaded_e │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ NA                        │
# │ 2   │ NA                │ NA                        │
# │ 3   │ NA                │ NA                        │
#
# │ Row │ params_nt_domcontloaded_st │ params_nt_domint │ params_nt_domloading │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                         │ NA               │ NA                   │
# │ 2   │ NA                         │ NA               │ NA                   │
# │ 3   │ NA                         │ NA               │ NA                   │
#
# │ Row │ params_nt_fet_st │ params_nt_first_paint │ params_nt_load_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA                    │ NA                 │
# │ 2   │ NA               │ NA                    │ NA                 │
# │ 3   │ NA               │ NA                    │ NA                 │
#
# │ Row │ params_nt_load_st │ params_nt_nav_st │ params_nt_nav_type │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ NA               │ NA                 │
# │ 2   │ NA                │ NA               │ NA                 │
# │ 3   │ NA                │ NA               │ NA                 │
#
# │ Row │ params_nt_red_cnt │ params_nt_red_end │ params_nt_red_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                │ NA                │ NA               │
# │ 2   │ NA                │ NA                │ NA               │
# │ 3   │ NA                │ NA                │ NA               │
#
# │ Row │ params_nt_req_st │ params_nt_res_end │ params_nt_res_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA                │ NA               │
# │ 2   │ NA               │ NA                │ NA               │
# │ 3   │ NA               │ NA                │ NA               │
#
# │ Row │ params_nt_spdy │ params_nt_ssl_st │ params_nt_unload_end │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA               │ NA                   │
# │ 2   │ NA             │ NA               │ NA                   │
# │ 3   │ NA             │ NA               │ NA                   │
#
# │ Row │ params_nt_unload_st │ params_nu │ params_pgu │ params_r                │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA        │ NA         │ NA                      │
# │ 2   │ NA                  │ NA        │ NA         │ NA                      │
# │ 3   │ NA                  │ NA        │ NA         │ "http://m.facebook.com" │
#
# │ Row │ params_r2 │ params_rt_abld │ params_rt_blstart │ params_rt_bmr_conen │
# ┝━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA        │ NA             │ 1489675981580     │ NA                  │
# │ 2   │ NA        │ NA             │ 1489676116143     │ NA                  │
# │ 3   │ NA        │ NA             │ 1489676285198     │ NA                  │
#
# │ Row │ params_rt_bmr_const │ params_rt_bmr_domen │ params_rt_bmr_domst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_bmr_fetst │ params_rt_bmr_reqst │ params_rt_bmr_resen │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_bmr_resst │ params_rt_bmr_secst │ params_rt_bstart │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ 1489675983397    │
# │ 2   │ NA                  │ NA                  │ 1489676117948    │
# │ 3   │ NA                  │ NA                  │ 1489676287755    │
#
# │ Row │ params_rt_cnf_conen │ params_rt_cnf_const │ params_rt_cnf_domen │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_cnf_domst │ params_rt_cnf_fetst │ params_rt_cnf_reqst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_cnf_resen │ params_rt_cnf_resst │ params_rt_cnf_secst │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA                  │ NA                  │
# │ 2   │ NA                  │ NA                  │ NA                  │
# │ 3   │ NA                  │ NA                  │ NA                  │
#
# │ Row │ params_rt_cstart │ params_rt_end │ params_rt_ntvu │ params_rt_obo │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ 1489675975075 │ NA             │ NA            │
# │ 2   │ NA               │ 1489676211016 │ NA             │ NA            │
# │ 3   │ NA               │ 1489676286708 │ NA             │ NA            │
#
# │ Row │ params_rt_quit │ params_rt_sh │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA           │
# │ 2   │ NA             │ NA           │
# │ 3   │ NA             │ NA           │
#
# │ Row │ params_rt_si                                  │ params_rt_sl │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ "9e667e71-936e-4ec0-bf44-2cb93403c294-omwxc6" │ 1            │
# │ 2   │ "835eb4f2-718c-4091-be95-63d6cb86d6db-omwxff" │ 1            │
# │ 3   │ "b99ce00b-a834-4f0b-8a6a-ab257cb57391-omwxkq" │ 1            │
#
# │ Row │ params_rt_srst │ params_rt_start │ params_rt_tstart │ params_rt_tt │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA              │ 1489675973925    │ NA           │
# │ 2   │ NA             │ NA              │ 1489676090930    │ NA           │
# │ 3   │ NA             │ NA              │ 1489676282019    │ NA           │
#
# │ Row │ params_scr_bpp │ params_scr_dpx │ params_scr_mtp │ params_scr_orn │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ "32/32"        │ 2.0            │ NA             │ NA             │
# │ 2   │ "32/32"        │ 1.5            │ NA             │ NA             │
# │ 3   │ "32/32"        │ 2.0            │ NA             │ NA             │
#
# │ Row │ params_scr_xy │
# ┝━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ "768x1024"    │
# │ 2   │ "540x960"     │
# │ 3   │ "320x568"     │
#
# │ Row │ params_u                                                                                                                                                                                                                │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "http://news.nationalgeographic.com/news/energy/2013/04/130423-reshaping-flight-for-fuel-efficiency/"                                                                                                                   │
# │ 2   │ "http://news.nationalgeographic.com/2017/03/snakes-pythons-africa-hyena-kill/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170315news-snakehyena&utm_campaign=Content&sf62899593=1"                       │
# │ 3   │ "http://www.nationalgeographic.com/photography/proof/2017/02/atomic-rooms-beijing-china-housing/?utm_source=Facebook&utm_medium=Social&utm_content=link_fbp20170315photo-atomicrooms&utm_campaign=Content&sf62021278=1" │
#
# │ Row │ params_v           │ params_vis_lh │ params_vis_lv │ params_vis_st │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ "1.405.1475087321" │ NA            │ NA            │ "hidden"      │
# │ 2   │ "1.405.1475087321" │ NA            │ NA            │ "visible"     │
# │ 3   │ "1.405.1475087321" │ NA            │ NA            │ "visible"     │
#
# │ Row │ proxy_address    │ remote_ip         │ session_id │ session_isunload │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "162.158.89.190" │ "95.70.197.157"   │ NA         │ NA               │
# │ 2   │ "188.114.102.19" │ "93.40.106.237"   │ NA         │ NA               │
# │ 3   │ "162.158.38.37"  │ "213.233.132.139" │ NA         │ NA               │
#
# │ Row │ session_latest │ session_obopages │ session_pages │ session_start │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA               │ NA            │ NA            │
# │ 2   │ NA             │ NA               │ NA            │ NA            │
# │ 3   │ NA             │ NA               │ NA            │ NA            │
#
# │ Row │ session_totalloadtime │ spdy │ ssl │ timers_before_dns │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━┿━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                    │ NA   │ NA  │ NA                │
# │ 2   │ NA                    │ NA   │ NA  │ NA                │
# │ 3   │ NA                    │ NA   │ NA  │ NA                │
#
# │ Row │ timers_boomerang │ timers_boomr_fb │ timers_boomr_lat │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA              │ NA               │
# │ 2   │ NA               │ NA              │ NA               │
# │ 3   │ NA               │ NA              │ NA               │
#
# │ Row │ timers_boomr_ld │ timers_boomr_to_end │ timers_custom0 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA              │ NA                  │ NA             │
# │ 2   │ NA              │ NA                  │ NA             │
# │ 3   │ NA              │ NA                  │ NA             │
#
# │ Row │ timers_custom1 │ timers_custom2 │ timers_custom3 │ timers_custom4 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA             │ NA             │ NA             │
# │ 2   │ NA             │ NA             │ NA             │ NA             │
# │ 3   │ NA             │ NA             │ NA             │ NA             │
#
# │ Row │ timers_custom5 │ timers_custom6 │ timers_custom7 │ timers_custom8 │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA             │ NA             │ NA             │
# │ 2   │ NA             │ NA             │ NA             │ NA             │
# │ 3   │ NA             │ NA             │ NA             │ NA             │
#
# │ Row │ timers_custom9 │ timers_dns │ timers_domload │ timers_domready │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA         │ NA             │ NA              │
# │ 2   │ NA             │ NA         │ NA             │ NA              │
# │ 3   │ NA             │ NA         │ NA             │ NA              │
#
# │ Row │ timers_fb_to_boomr │ timers_loaded │ timers_missing │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA            │ NA             │
# │ 2   │ NA                 │ NA            │ NA             │
# │ 3   │ NA                 │ NA            │ NA             │
#
# │ Row │ timers_navst_to_boomr │ timers_renderstart │ timers_ssl │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┥
# │ 1   │ NA                    │ NA                 │ NA         │
# │ 2   │ NA                    │ NA                 │ NA         │
# │ 3   │ NA                    │ NA                 │ NA         │
#
# │ Row │ timers_t_configfb │ timers_t_configjs │ timers_t_domloaded │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 237               │ 242               │ NA                 │
# │ 2   │ 378               │ 388               │ NA                 │
# │ 3   │ 4150              │ 351               │ NA                 │
#
# │ Row │ timers_t_done │ timers_t_load │ timers_t_page │ timers_t_postrender │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA            │ NA            │ NA            │ NA                  │
# │ 2   │ NA            │ NA            │ NA            │ NA                  │
# │ 3   │ NA            │ NA            │ NA            │ NA                  │
#
# │ Row │ timers_t_prerender │ timers_t_resp │ timers_tcp │ timestamp     │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA            │ NA         │ 1489675996722 │
# │ 2   │ NA                 │ NA            │ NA         │ 1489676228775 │
# │ 3   │ NA                 │ NA            │ NA         │ 1489676295804 │
#
# │ Row │ url                                   │ user_agent_family │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "http://news.nationalgeographic.com/" │ "Mobile Safari"   │
# │ 2   │ "http://news.nationalgeographic.com/" │ "Facebook"        │
# │ 3   │ "http://www.nationalgeographic.com/"  │ "Facebook"        │
#
# │ Row │ user_agent_major │ user_agent_minor │ user_agent_mobile │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 10               │ 0                │ "0"               │
# │ 2   │ 101              │ 0                │ "1"               │
# │ 3   │ 83               │ 0                │ "1"               │
#
# │ Row │ user_agent_model │ user_agent_os │ user_agent_osversion │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "iPad"           │ "iOS"         │ "10"                 │
# │ 2   │ NA               │ "Android OS"  │ "4"                  │
# │ 3   │ "iPhone"         │ "iOS"         │ "10"                 │
#
# │ Row │ user_agent_raw                                                                                                                                                                                                                                                          │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X) AppleWebKit/602.4.6 (KHTML, like Gecko) Version/10.0 Mobile/14D27 Safari/602.1"                                                                                                                                        │
# │ 2   │ "Mozilla/5.0 (Linux; U; Android 4.2.1; it-it; HUAWEI G610-U20 Build/HuaweiG610-U20) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30 [FB_IAB/FB4A;FBAV/101.0.0.18.70;]"                                                                          │
# │ 3   │ "Mozilla/5.0 (iPhone; CPU iPhone OS 10_2_1 like Mac OS X) AppleWebKit/602.4.6 (KHTML, like Gecko) Mobile/14D27 [FBAN/FBIOS;FBAV/83.0.0.38.70;FBBV/51754296;FBDV/iPhone6,2;FBMD/iPhone;FBSN/iOS;FBSV/10.2.1;FBSS/2;FBCR/vodafoneIE;FBID/phone;FBLC/el_GR;FBOP/5;FBRV/0]" │
#
# │ Row │ warnings                    │ beacon_type │ site_version │ ab_test │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━┥
# │ 1   │ "[\"referrer-url-mismatch\"]" │ "error"     │ NA           │ NA      │
# │ 2   │ "[\"referrer-url-mismatch\"]" │ "error"     │ NA           │ NA      │
# │ 3   │ "[\"referrer-url-mismatch\"]" │ "error"     │ NA           │ NA      │
#
# │ Row │ ipv6 │ user_agent_manufacturer │ user_agent_device_type │
# ┝━━━━━┿━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA   │ "Apple"                 │ "Tablet"               │
# │ 2   │ NA   │ "Huawei"                │ "Mobile"               │
# │ 3   │ NA   │ "Apple"                 │ "Mobile"               │
#
# │ Row │ user_agent_isp │ geo_isp                           │ bandwidth_kbps │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ "TurkNet Iletisim Hizmetleri A.S" │ NA             │
# │ 2   │ NA             │ "Fastweb"                         │ NA             │
# │ 3   │ NA             │ "Vodafone Ireland Limited"        │ NA             │
#
# │ Row │ bandwidth_error_pc │ bandwidth_block │ headers_cf_visitor │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA              │ NA                 │
# │ 2   │ NA                 │ NA              │ NA                 │
# │ 3   │ NA                 │ NA              │ NA                 │
#
# │ Row │ headers_cf_ray │ headers_cf_connecting_ip │ headers_x_forwarded_for │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA                       │ NA                      │
# │ 2   │ NA             │ NA                       │ NA                      │
# │ 3   │ NA             │ NA                       │ NA                      │
#
# │ Row │ headers_x_forwarded_proto │ headers_connection │ headers_host │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ NA                        │ NA                 │ NA           │
# │ 2   │ NA                        │ NA                 │ NA           │
# │ 3   │ NA                        │ NA                 │ NA           │
#
# │ Row │ headers_accept_encoding │ headers_accept_language │ headers_accept │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                      │ NA                      │ NA             │
# │ 2   │ NA                      │ NA                      │ NA             │
# │ 3   │ NA                      │ NA                      │ NA             │
#
# │ Row │ headers_content_length │ headers_various │ params_dom_img_ext │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                     │ NA              │ NA                 │
# │ 2   │ NA                     │ NA              │ 7                  │
# │ 3   │ NA                     │ NA              │ NA                 │
#
# │ Row │ params_dom_script_ext │ params_ua_plt  │ params_ua_vnd          │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 29                    │ "iPad"         │ "Apple Computer, Inc." │
# │ 2   │ 39                    │ "Linux armv7l" │ "Google Inc."          │
# │ 3   │ 31                    │ "iPhone"       │ "Apple Computer, Inc." │
#
# │ Row │ http_errno │ params_http_method │ params_http_hdr │
# ┝━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA         │ NA                 │ NA              │
# │ 2   │ NA         │ NA                 │ NA              │
# │ 3   │ NA         │ NA                 │ NA              │
#
# │ Row │ params_http_initiator │ params_h_cr │ params_xhr_sync │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                    │ NA          │ NA              │
# │ 2   │ NA                    │ NA          │ NA              │
# │ 3   │ NA                    │ NA          │ NA              │
#
# │ Row │ params_rt_subres │ params_bw_time │ params_lat │ params_lat_err │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA               │ NA             │ NA         │ NA             │
# │ 2   │ NA               │ NA             │ NA         │ NA             │
# │ 3   │ NA               │ NA             │ NA         │ NA             │
#
# │ Row │ params_mob_ct │ cdim │ params_nt_cinf │ params_rt_ss │
# ┝━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┥
# │ 1   │ NA            │ "[]" │ NA             │ 1.48968e12   │
# │ 2   │ NA            │ "[]" │ NA             │ 1.48968e12   │
# │ 3   │ NA            │ "[]" │ NA             │ 1.48968e12   │
#
# │ Row │ errors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "[{\"count\":1,\"timestamp\":1489675980078,\"message\":\"undefined is not an object\",\"functionName\":\"keys\",\"fileName\":\"[native code]\",\"stack\":\"undefined is not an object (evaluating 'Ja(Ga(a)?T(a):a)') at keys ([native code])\\nat keys (http://news.nationalgeographic.com/etc/designs/platform/v2/scripts/ngs-vendor.ngsversion.e2d5317d.js:16:4892)\\nat prune (http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791:2:310719)\\nat add (http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791:2:310504)\\nat o (http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791:2:311728)\\nat r (http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791:2:204154)\\nat http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791:2:194108\\nat onReady (http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791:2:192715)\\nat http://c.go-mpulse.net/boomerang/M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT:13:11950\",\"type\":\"TypeError\",\"source\":\"app\",\"via\":\"timeout\",\"frames\":[{\"fileName\":\"[native code]\",\"functionName\":\"keys\"},{\"fileName\":\"http://news.nationalgeographic.com/etc/designs/platform/v2/scripts/ngs-vendor.ngsversion.e2d5317d.js\",\"functionName\":\"keys\",\"lineNumber\":16,\"columnNumber\":4892},{\"fileName\":\"http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791\",\"functionName\":\"prune\",\"lineNumber\":2,\"columnNumber\":310719},{\"fileName\":\"http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791\",\"functionName\":\"add\",\"lineNumber\":2,\"columnNumber\":310504},{\"fileName\":\"http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791\",\"functionName\":\"o\",\"lineNumber\":2,\"columnNumber\":311728},{\"fileName\":\"http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791\",\"functionName\":\"r\",\"lineNumber\":2,\"columnNumber\":204154},{\"fileName\":\"http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791\",\"lineNumber\":2,\"columnNumber\":194108},{\"fileName\":\"http://s7.addthis.com/js/300/addthis_widget.js?_=1489675984791\",\"functionName\":\"onReady\",\"lineNumber\":2,\"columnNumber\":192715},{\"fileName\":\"http://c.go-mpulse.net/boomerang/M2ZXH-3ZAA3-MSZ2Y-KK6SL-QWHPT\",\"lineNumber\":13,\"columnNumber\":11950}]}]" │
# │ 2   │ "[{\"count\":1,\"timestamp\":1489676225976,\"message\":\"TypeError: Cannot read property 'controller' of undefined\",\"fileName\":\"http://news.nationalgeographic.com/2017/03/snakes-pythons-africa-hyena-kill/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170315news-snakehyena&utm_campaign=Content&sf62899593=1\",\"lineNumber\":161,\"stack\":\"Uncaught TypeError: Cannot read property 'controller' of undefined at http://news.nationalgeographic.com/2017/03/snakes-pythons-africa-hyena-kill/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170315news-snakehyena&utm_campaign=Content&sf62899593=1:161\",\"type\":\"Error\",\"source\":\"app\",\"via\":\"global exception handler\",\"frames\":[{\"fileName\":\"http://news.nationalgeographic.com/2017/03/snakes-pythons-africa-hyena-kill/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20170315news-snakehyena&utm_campaign=Content&sf62899593=1\",\"lineNumber\":161}]}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │
# │ 3   │ "[{\"count\":1,\"timestamp\":1489676286818,\"message\":\"Script error\",\"stack\":\"Script error.\",\"type\":\"Error\",\"source\":\"app\",\"via\":\"global exception handler\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                │
#
# │ Row │ tp_ga_clientid │ tp_ga_utm_source │ tp_ga_utm_medium │ tp_ga_utm_term │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA               │ NA               │ NA             │
# │ 2   │ NA             │ NA               │ NA               │ NA             │
# │ 3   │ NA             │ NA               │ NA               │ NA             │
#
# │ Row │ tp_ga_utm_content │ tp_ga_utm_campaign │ tp_aa_aid │ tp_aa_mid │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━┥
# │ 1   │ NA                │ NA                 │ NA        │ NA        │
# │ 2   │ NA                │ NA                 │ NA        │ NA        │
# │ 3   │ NA                │ NA                 │ NA        │ NA        │
#
# │ Row │ tp_aa_campaign │ tp_ia_coreid │ tp_ia_mmc_vendor │ tp_ia_mmc_category │
# ┝━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA             │ NA           │ NA               │ NA                 │
# │ 2   │ NA             │ NA           │ NA               │ NA                 │
# │ 3   │ NA             │ NA           │ NA               │ NA                 │
#
# │ Row │ tp_ia_mmc_placement │ tp_ia_mmc_item │ tp_ia_sp_type │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┥
# │ 1   │ NA                  │ NA             │ NA            │
# │ 2   │ NA                  │ NA             │ NA            │
# │ 3   │ NA                  │ NA             │ NA            │
#
# │ Row │ tp_ia_sp_promotion │ tp_ia_sp_link │ tp_ia_re_version │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┥
# │ 1   │ NA                 │ NA            │ NA               │
# │ 2   │ NA                 │ NA            │ NA               │
# │ 3   │ NA                 │ NA            │ NA               │
#
# │ Row │ tp_ia_re_pagearea │ tp_ia_re_link │ tp_aa_purchaseid │ beacon_id │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━┥
# │ 1   │ NA                │ NA            │ NA               │ NA        │
# │ 2   │ NA                │ NA            │ NA               │ NA        │
# │ 3   │ NA                │ NA            │ NA               │ NA        │

# %%
***
## RT Counts And Time Ranges In DSWB
***

# %%
setTable("beacons_4744_rt", tableType = "RESOURCE_TABLE");

rtcnt = query("""select count(*) from beacons_4744_rt""");

# %%
maxRt = query("""\
select max("timestamp") from beacons_4744_rt
""");

minRt = query("""\
select min("timestamp") from beacons_4744_rt
""");

minStr = msToDateTime(minRt[1,:min]);
maxStr = msToDateTime(maxRt[1,:max]);

printDf = DataFrame();
printDf[:minStr] = minStr;
printDf[:maxStr] = maxStr;
;

# %%
beautifyDF(names!(rtcnt[:,:],[symbol("Resource Timing Count")]))
beautifyDF(names!(printDf[:,:],[symbol("First RT"),symbol("Last RT")]))
