# %% [markdown]
# ## Tables and Data Source setup

# %%
using ODBC
using DataFrames
using DSWB
using Formatting

dsn = "dswb-natgeo" # Redshift esetTable(tableRt, tableType = "RESOURCE_TABLE")ndpoint
table = "beacons_4744" # beacon table name
tableRt = "beacons_4744_rt"

# Connect to Beacon Data
setRedshiftEndpoint(dsn)
setTable(table)
setTable(tableRt, tableType = "RESOURCE_TABLE")
# Out:
# Redshift endpoint set: 2017-11-16T01:46:53
# "beacons_4744_rt"

# %%
# Packages
include("/data/notebook_home/Production/Lib/Include-Package-v1.0.jl")
include("/data/notebook_home/Production/Bodies/Url-Details-Body-v1.0.jl")

#weeklyTimeVariables(days=1)
#yesterdayTimeVariables()
timeVariables(2017,11,13,11,59,2017,11,13,15,59)
;
# Out:
# November 13, 2017 11:59:00 to November 13, 2017 15:59:00 Local Time
# November 13, 2017 16:59:00 to November 13, 2017 20:59:00 UTC Time

# %%
UP = UrlParamsInit()
UP.beaconTable = table   #table
UP.resourceTable = tableRt
UP.btView = "$(table)_URL_Details_view_prod" #localtable
UP.rtView = "$(tableRt)_URL_Details_view_prod" #localtableRt
UP.pageGroup = "News Article"   #productPageGroup
UP.urlRegEx = "%news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd%"   #localUrl
UP.urlFull = "http://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/"
#UP.deviceType = "Mobile"

SG = SoastaGraphsInit()
customer = "Nat Geo" 
SG.customer = customer

SP = ShowParamsInit()
SP.debugLevel = 10;
SP.debug = true;
SP.showLines = 25

;

# %%
defaultBeaconViewUDB(tv,UP)
;
# Out:
# beacons_4744_URL_Details_view_prod count is (9244,246)

# %%
defaultResourceView(tv,UP)
;
# Out:
# beacons_4744_rt_URL_Details_view_prod count is (867862,27)

# %% [markdown]
# ***
#
# ## Start Analyzing The Local Data Set Specific to URL and Time Range
#
# ***

# %%
#displayTitle(chart_title = "Concurrent Sessions and Beacons for $(productPageGroup)", chart_info = [timeString])
chartConcurrentSessionsAndBeaconsOverTime(tv.startTimeUTC, tv.endTimeUTC, tv.datePart)
# Out:
# <div class="dswbOutputText">
#     <strong><span class="chart_info" style="color:#B1D6ED;">Using session timeout value of 30 minutes...</strong>
# </div>
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Concurrent Sessions and Beacons by minute</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:48:16</h5></div>
#     <iframe id="timeSeries-QNMJMIRLLNUBDQKMEBKTRDCRMWUNWCLT" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#     <script>
#     (function() {
#         var iframe = document.getElementById("timeSeries-QNMJMIRLLNUBDQKMEBKTRDCRMWUNWCLT");
#         iframe.timeSeriesRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner([["x","2017-11-13 17:32:00","2017-11-13 17:34:00","2017-11-13 17:35:00","2017-11-13 17:36:00","2017-11-13 17:37:00","2017-11-13 17:39:00","2017-11-13 17:40:00","2017-11-13 17:41:00","2017-11-13 17:42:00","2017-11-13 17:43:00","2017-11-13 17:44:00","2017-11-13 17:45:00","2017-11-13 17:46:00","2017-11-13 17:47:00","2017-11-13 17:48:00","2017-11-13 17:49:00","2017-11-13 17:50:00","2017-11-13 17:51:00","2017-11-13 17:52:00","2017-11-13 17:53:00","2017-11-13 17:54:00","2017-11-13 17:55:00","2017-
19:53:00","2017-11-13 19:54:00","2017-11-13 19:55:00","2017-11-13 19:56:00","2017-11-13 19:57:00","2017-11-13 19:58:00","2017-11-13 19:59:00","2017-11-13 20:00:00","2017-11-13 20:01:00","2017-11-13 20:02:00","2017-11-13 20:03:00","2017-11-13 20:04:00","2017-11-13 20:05:00","2017-11-13 20:06:00","2017-11-13 20:07:00","2017-11-13 20:08:00","2017-11-13 20:09:00","2017-11-13 20:10:00","2017-11-13 20:11:00","2017-11-13 20:12:00","2017-11-13 20:13:00","2017-11-13 20:14:00","2017-11-13 20:15:00","2017-11-13 20:16:00","2017-11-13 20:17:00","2017-11-13 20:18:00","2017-11-13 20:19:00","2017-11-13 20:20:00","2017-11-13 20:21:00","2017-11-13 20:22:00","2017-11-13 20:23:00","2017-11-13 20:24:00","2017-11-13 20:25:00","2017-11-13 20:26:00","2017-11-13 20:27:00","2017-11-13 20:28:00","2017-11-13 20:29:00","2017-11-13 20:30:00","2017-11-13 20:31:00","2017-11-13 20:32:00","2017-11-13 20:33:00","2017-11 ...
#                 ["Sessions","Beacons"],
#                 ["minute","Concurrent Sessions","Beacon Count"],
#                 ["area-spline","bar"],
#                 ["hsla(28, 100%, 86%, 0.9)","hsla(197, 70%, 73%, 0.9)"],
#                 [],
#                 ["data2"],
#                 "    .c3-line {\n        stroke: #039BE5;\n    }\n\n    .c3-area {\n        opacity:0.4;\n    }\n\n    .c3 text {\n        stroke: #979797 !important;\n    }\n",
#                 [],
#                 {"point_r":0,"axis_y_min":0,"axis_x_tick_culling_max":20,"axis_y2_min":0}
#             );
#         }
#         iframe.src = "/static/graphs/templates/c3Viz_template.html#id=timeSeries-QNMJMIRLLNUBDQKMEBKTRDCRMWUNWCLT";
#     }());
#     </script>

# %%
chartLoadTimes(tv.startTimeUTC, tv.endTimeUTC, tv.datePart, pageUrl=UP.urlRegEx)
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Median Load Times</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:48:22</h5></div>
#     <iframe id="timeSeries-MOVJQGJTOOZSCTBUASDDDUGQFNCJGPIC" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#     <script>
#     (function() {
#         var iframe = document.getElementById("timeSeries-MOVJQGJTOOZSCTBUASDDDUGQFNCJGPIC");
#         iframe.timeSeriesRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner([["x","November 13, 2017 16:59:00","November 13, 2017 17:00:00","November 13, 2017 17:01:00","November 13, 2017 17:02:00","November 13, 2017 17:03:00","November 13, 2017 17:04:00","November 13, 2017 17:05:00","November 13, 2017 17:06:00","November 13, 2017 17:07:00","November 13, 2017 17:08:00","November 13, 2017 17:09:00","November 13, 2017 17:10:00","November 13, 2017 17:11:00","November 13, 2017 17:12:00","November 13, 2017 17:13:00","November 13, 2017 17:14:00","November 13, 2017 17:15:00","November 13, 2017 17:16:00","November 13, 2017 17:17:00","November 13, 2017 17:18:00","November 13, 2017 17:19:00","November 13, 2017 17:20:00","November 13, 2017 17:21:00","November 13, 2017 17:22:00","November 13, 2017 17:23:00","November 13, 2017 17:24:00","November 13, 2017 17:25:00","November 13, 2017 17:26:00","November 13, 2017 17:27:00","November 13, 2017 17:28:00","November 13, 2017
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Top URL Page Views for News Article</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 11:59:00 to November 13, 2017 15:59:00 Local Time</h3></div>
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Views</th> <th class=\"cell-2\" style=\"\">Url - With Grouping After Parameters Dropped</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"text-align:right;\">9,161</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd</td></tr>\n    \n    <tr><td class=\"cell-1\" style=\"text-align:right;\">1</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/azija</td></tr>\n    </tbody>\n")

# %%
topUrlPageViewsUDB(TV,UP,SP)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Top URL Page Views for News Article</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 11:59:00 to November 13, 2017 15:59:00 Local Time</h3><h3 class="chart_info" style="color:#ccc">URL: %news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd%</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:48:30</h5></div>
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Views</th> <th class=\"cell-2\" style=\"\">Url - With Grouping After Parameters Dropped</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"text-align:right;\">6,655</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news-iranquake&utm_campaign=Content&sf166854614=1</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">2,136</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">272</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Twitter&utm_medium=Social&utm_content=link_tw20171113news-iranquake&utm_campaign=Content&sf166858006=1</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">60</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?sf166858006=1</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">22</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+ng%2FNews%2FNews_Main+%28National+Geographic+News+-+Main%29</td></tr>\n    \n    <tr><td class=\"cell-1\" style=\"text-align:right;\">11</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+ng%2FNews%2FNews_Main+%28National+Geographic+News+-+Main%29&utm_content=Yahoo+Search+Results</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">3</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Twitter&utm_medium=Social&utm_content=link_tw20171113news-iranquake&utm_campaign=Content&sf166858006=1&utm_campaign=Bundle&utm_medium=referral&utm_source=Bundle</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">1</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Facebook&utm_medium=Soc</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">1</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=dlvr.it&utm_medium=twitter</td></tr>\n<tr><td class=\"cell-1\" style=\"text-align:right;\">1</td> <td class=\"cell-2\" style=\"\">https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/azija/</td></tr>\n    </tbody>\n")

# %%
methods(chartTopPageResourcesSummary)
# Out:
# UndefVarError: chartTopPageResourcesSummary not defined

# %%
#fail thresholdValues = [1000, 10000, 100000]
#fail chartRes = chartResponseTimesVsTargets(startTime, endTime, datePart, thresholdValues)
setTable(UP.rtView, tableType = "RESOURCE_TABLE")
try
    chartRes = chartTopPageResourcesSummary(tv.startTimeUTC, tv.endTimeUTC, beaconTable=UP.btView, resourceTable=UP.rtView,n=10,minPercentage=0.05)
    display(chartRes[1:20,:])
catch y
    println("chartTop LocalTable Exception ",y)
end

setTable(UP.btView)
# Out:
# chartTop LocalTable Exception UndefVarError(:chartTopPageResourcesSummary)
# "beacons_4744_URL_Details_view_prod"

# %%
chartMedianLoadTimesByDimension(tv.startTimeUTC,tv.endTimeUTC,dimension=:url,minPercentage=0.1)
chartMedianLoadTimesByDimension(tv.startTimeUTC,tv.endTimeUTC,dimension=:params_u,minPercentage=0.1)
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Median Load Times by url</h1><h3 class="chart_info" style="color:#ccc">Stacked Back-end and Front-end Load Times</h3><h3 class="chart_info" style="color:#ccc">From November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:48:46</h5></div>
#     <iframe id="timeSeries-MSRGMTITSWFLVHIVHMHJTHGNBWRVVUQS" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#     <script>
#     (function() {
#         var iframe = document.getElementById("timeSeries-MSRGMTITSWFLVHIVHMHJTHGNBWRVVUQS");
#         iframe.timeSeriesRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner([["x","https://news.nationalgeographic.com/"],["data1",808.0],["data2",11151.0]],
#                 ["Back End Load Time","Front end Load Time"],
#                 ["url","Load Times (ms)"],
#                 ["bar","bar"],
#                 ["hsla(130, 61%, 50%, 0.9)","hsla(214, 86%, 60%, 0.9)"],
#                 [["data1","data2"]],
#                 [],
#                 "",
#                 [],
#                 {"axis_y_min":0}
#             );
#         }
#         iframe.src = "/static/graphs/templates/c3VizRotated_template.html#id=timeSeries-MSRGMTITSWFLVHIVHMHJTHGNBWRVVUQS";
#     }());
#     </script>
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Median Load Times by params_u</h1><h3 class="chart_info" style="color:#ccc">Stacked Back-end and Front-end Load Times</h3><h3 class="chart_info" style="color:#ccc">From November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:48:49</h5></div>
#     <iframe id="timeSeries-EDPQKCOHSWQWVTHLRZLNILNHJWXOCJCF" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#     <script>
#     (function() {
#         var iframe = document.getElementById("timeSeries-EDPQKCOHSWQWVTHLRZLNILNHJWXOCJCF");
#         iframe.timeSeriesRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner([["x","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+ng%2FNews%2FNews_Main+%28National+Geographic+News+-+Main%29&utm_content=Yahoo+Search+Results","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news-iranquake&utm_campaign=Content&sf166854614=1","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Twitter&utm_medium=Social&utm_content=link_tw20171113news-iranquake&utm_campaign=Content&sf166858006=1","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+ng%2FNews%2FNews_Main+%28National+Geographic+News+-+Main%29","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?sf166858006=1"],["data1",364.0,962.0,865.0,402.0,477.0,178.5],["data2",13335.0,12522.0,8557.5,7879.0,7090.0,6534.0]],
#                 ["Back End Load Time","Front end Load Time"],
#                 ["params_u","Load Times (ms)"],
#                 ["bar","bar"],
#                 ["hsla(130, 61%, 50%, 0.9)","hsla(214, 86%, 60%, 0.9)"],
#                 [["data1","data2"]],
#                 [],
#                 "",
#                 [],
#                 {"axis_y_min":0}
#             );
#         }
#         iframe.src = "/static/graphs/templates/c3VizRotated_template.html#id=timeSeries-EDPQKCOHSWQWVTHLRZLNILNHJWXOCJCF";
#     }());
#     </script>

# %%
setTable(UP.rtView, tableType = "RESOURCE_TABLE")
chartRes = chartCacheHitRatioByUrl(tv.startTimeUTC, tv.endTimeUTC, minPercentage=0.1)
setTable(UP.btView)
display(chartRes)
# Out:
# UndefVarError: chartCacheHitRatioByUrl not defined

# %%
#setTable(localTableRt, tableType = "RESOURCE_TABLE")
#chartTopPageResourcesSummary(startTime, endTime)
#chartTopPageResourcesSummary(startTime, endTime, datepart = datePart)
#setTable(localTable)
#display(chartRes)

# %%
setTable(UP.rtView, tableType = "RESOURCE_TABLE")
chartRes = chartResourceResponseTimeDistribution(tv.startTimeUTC, tv.endTimeUTC,url=UP.urlRegEx)
setTable(UP.btView)
display(chartRes)
# Out:
# UndefVarError: getResourceResponseTimeDistribution not defined
#
#  in chartResourceResponseTimeDistribution at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBCharting/src/DSWBCharting.jl:1554

# %%
setTable(UP.rtView, tableType = "RESOURCE_TABLE")
#chartRes = chartResourceResponseTimeDistribution(startTime, endTime,url="http://phenomena.nationalgeographic.com/files/2016/05/BH91DH.jpg")
chartRes = chartResourceResponseTimeDistribution(tv.startTimeUTC, tv.endTimeUTC)
setTable(UP.btView)
display(chartRes)
# Out:
# UndefVarError: getResourceResponseTimeDistribution not defined
#
#  in chartResourceResponseTimeDistribution at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBCharting/src/DSWBCharting.jl:1554

# %%
chartPercentageOfBeaconsBelowThresholdStackedBar(tv.startTimeUTC, tv.endTimeUTC, tv.datePart; pageGroup =UP.pageGroup, threshold = 6000, url=UP.urlRegEx)
# Out:
# ArgumentError: Non-digit character encountered
#
#  in getslot at dates/io.jl:143
#  in parse at dates/io.jl:158
#  in call at dates/io.jl:202
#  in anonymous at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBUtilities/src/DSWBUtilities.jl:1152
#  [inlined code] from /home/ubuntu/.julia/v0.4/DataArrays/src/broadcast.jl:59
#  in _F_ at /home/ubuntu/.julia/v0.4/DataArrays/src/broadcast.jl:164
#  in map! at /home/ubuntu/.julia/v0.4/DataArrays/src/broadcast.jl:214
#  in formatDatepartOutput at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBUtilities/src/DSWBUtilities.jl:1152
#  in getBeaconsBelowThresholdOverTime at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBAnalysis/src/DSWBAnalysis.jl:3730
#  in chartPercentageOfBeaconsBelowThresholdStackedBar at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBCharting/src/DSWBCharting.jl:2029

# %%
chartBouncesVsLoadTimes(tv.startTimeUTC, tv.endTimeUTC, url=UP.urlFull)
#chartBouncesVsLoadTimes(startTime, endTime)
# Out:
# ArgumentError: Length of nms doesn't match length of x.
#
#  in names! at /home/ubuntu/.julia/v0.4/DataFrames/src/other/index.jl:28
#  in names! at /home/ubuntu/.julia/v0.4/DataFrames/src/abstractdataframe/abstractdataframe.jl:129
#  in getBounceRateByLoadTime at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBAnalysis/src/DSWBAnalysis.jl:4261
#  in chartBouncesVsLoadTimes at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBCharting/src/DSWBCharting.jl:898

# %% [markdown]
# ***
#
# ##Examine Load Times
#
# ***

# %%
setTable(UP.rtView, tableType = "RESOURCE_TABLE")
responseDist = getResourceResponseTimeDistribution(tv.startTimeUTC,tv.endTimeUTC, n=15, url=UP.urlFull)
setTable(UP.btView)
display(responseDist)
# Out:
# UndefVarError: getResourceResponseTimeDistribution not defined

# %%
#localTableRtDF[Bool[ismatch(r".*transamerica.*",x) for x in localTableRtDF[:url]],:]

# %%
#localTableRtDF[Bool[ismatch(r".*goldengatefog.*",x) for x in localTableRtDF[:url]],:]

# %%
perfsessionLength = getAggregateSessionLengthAndDurationByLoadTime(tv.startTimeUTC, tv.endTimeUTC, url=UP.urlFull)
c3 = drawC3Viz(perfsessionLength; columnNames=[:load_time,:total,:avg_length], axisLabels=["Page Load Times","Completed Sessions", "Average Session Length"],dataNames=["Completed Sessions", 
    "Average Session Length", "Average Session Duration"], mPulseWidget=false, chart_title="Top URL Page Load for $(productPageGroup) Page Group", y2Data=["data2"], vizTypes=["area","line"])
;
# Out:
# unrecognized keyword argument "url"
#
#  in getAggregateSessionLengthAndDurationByLoadTime at /home/ubuntu/datascienceworkbench/lib/Modules/DSWBAnalysis/src/DSWBAnalysis.jl:1341

# %%
#chartLoadTimes(startTime, endTime, :minute, pageGroup=productPageGroup)
#chartLoadTimes(startTime, endTime, :minute)

chartMedianLoadTimesByDimension(tv.startTimeUTC, tv.endTimeUTC; dimension=:user_agent_device_type, n=15, orderBy="frontend", minPercentage=0.001)
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Median Load Times by user_agent_device_type</h1><h3 class="chart_info" style="color:#ccc">Stacked Back-end and Front-end Load Times</h3><h3 class="chart_info" style="color:#ccc">From November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:49:33</h5></div>
#     <iframe id="timeSeries-TNETOHTJBFRTYHFIKGXFQPQBIIFLKEFM" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#     <script>
#     (function() {
#         var iframe = document.getElementById("timeSeries-TNETOHTJBFRTYHFIKGXFQPQBIIFLKEFM");
#         iframe.timeSeriesRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner([["x","Tablet","Mobile","Desktop"],["data1",644.0,984.0,544.0],["data2",20091.5,14727.0,6464.0]],
#                 ["Back End Load Time","Front end Load Time"],
#                 ["user_agent_device_type","Load Times (ms)"],
#                 ["bar","bar"],
#                 ["hsla(130, 61%, 50%, 0.9)","hsla(214, 86%, 60%, 0.9)"],
#                 [["data1","data2"]],
#                 [],
#                 "",
#                 [],
#                 {"axis_y_min":0}
#             );
#         }
#         iframe.src = "/static/graphs/templates/c3VizRotated_template.html#id=timeSeries-TNETOHTJBFRTYHFIKGXFQPQBIIFLKEFM";
#     }());
#     </script>

# %%
chartMedianLoadTimesByDimension(tv.startTimeUTC,tv.endTimeUTC,dimension=:geo_cc,minPercentage=2.5,n=10)
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Median Load Times by geo_cc</h1><h3 class="chart_info" style="color:#ccc">Stacked Back-end and Front-end Load Times</h3><h3 class="chart_info" style="color:#ccc">From November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:49:40</h5></div>
#     <iframe id="timeSeries-NCGQERKRKJHSEMKTNGPXVRYRQCBCLHYI" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#     <script>
#     (function() {
#         var iframe = document.getElementById("timeSeries-NCGQERKRKJHSEMKTNGPXVRYRQCBCLHYI");
#         iframe.timeSeriesRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner([["x","United Kingdom","Canada","United States"],["data1",780.0,637.5,578.0],["data2",12311.5,10419.0,8859.0]],
#                 ["Back End Load Time","Front end Load Time"],
#                 ["geo_cc","Load Times (ms)"],
#                 ["bar","bar"],
#                 ["hsla(130, 61%, 50%, 0.9)","hsla(214, 86%, 60%, 0.9)"],
#                 [["data1","data2"]],
#                 [],
#                 "",
#                 [],
#                 {"axis_y_min":0}
#             );
#         }
#         iframe.src = "/static/graphs/templates/c3VizRotated_template.html#id=timeSeries-NCGQERKRKJHSEMKTNGPXVRYRQCBCLHYI";
#     }());
#     </script>

# %% [markdown]
# ***
#
# ## Who Is Using This URL
#
# ***

# %%
localTable = UP.btView
productPageGroup = UP.pageGroup
customRefPGD(TV,UP)
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Custom Analytics Top Referrers for News Article</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 11:59:00 to November 13, 2017 15:59:00 Local Time</h3></div>
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Referral Group</th> <th class=\"cell-2\" style=\"\">Page Views</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">Facebook</td> <td class=\"cell-2\" style=\"text-align:right;\">7,241</td></tr>\n<tr><td class=\"cell-1\" style=\"\">Google</td> <td class=\"cell-2\" style=\"text-align:right;\">303</td></tr>\n    \n    <tr><td class=\"cell-1\" style=\"\">Reddit</td> <td class=\"cell-2\" style=\"text-align:right;\">0</td></tr>\n    </tbody>\n")
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Google Analytics Field: Source</th> <th class=\"cell-2\" style=\"\">Page Views</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">Facebook</td> <td class=\"cell-2\" style=\"text-align:right;\">5,664</td></tr>\n<tr><td class=\"cell-1\" style=\"\"></td> <td class=\"cell-2\" style=\"text-align:right;\">1,992</td></tr>\n<tr><td class=\"cell-1\" style=\"\">Twitter</td> <td class=\"cell-2\" style=\"text-align:right;\">249</td></tr>\n    \n    <tr><td class=\"cell-1\" style=\"\">feedburner</td> <td class=\"cell-2\" style=\"text-align:right;\">31</td></tr>\n<tr><td class=\"cell-1\" style=\"\">dlvr.it</td> <td class=\"cell-2\" style=\"text-align:right;\">1</td></tr>\n    </tbody>\n")
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Google Analytics Field: Medium</th> <th class=\"cell-2\" style=\"\">Page Views</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">Social</td> <td class=\"cell-2\" style=\"text-align:right;\">5,912</td></tr>\n<tr><td class=\"cell-1\" style=\"\"></td> <td class=\"cell-2\" style=\"text-align:right;\">1,992</td></tr>\n<tr><td class=\"cell-1\" style=\"\">feed</td> <td class=\"cell-2\" style=\"text-align:right;\">31</td></tr>\n    \n    <tr><td class=\"cell-1\" style=\"\">twitter</td> <td class=\"cell-2\" style=\"text-align:right;\">1</td></tr>\n<tr><td class=\"cell-1\" style=\"\">Soc</td> <td class=\"cell-2\" style=\"text-align:right;\">1</td></tr>\n    </tbody>\n")
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Google Analytics Field: Campaign</th> <th class=\"cell-2\" style=\"\">Page Views</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">Content</td> <td class=\"cell-2\" style=\"text-align:right;\">5,912</td></tr>\n<tr><td class=\"cell-1\" style=\"\"></td> <td class=\"cell-2\" style=\"text-align:right;\">1,994</td></tr>\n    \n    <tr><td class=\"cell-1\" style=\"\">Feed: ng/News/News_Main (National Geographic News - Main)</td> <td class=\"cell-2\" style=\"text-align:right;\">31</td></tr>\n    </tbody>\n")

# %%
stdRefPGD(TV,UP)
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Top 15 Referrers</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:49:58</h5></div>
#         <iframe id="donut-MQSBIQVTAWSGQJCRRQJVRKBQFXDQTNGB" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#         <script>
#         (function() {
#             var iframe = document.getElementById("donut-MQSBIQVTAWSGQJCRRQJVRKBQFXDQTNGB");
#             iframe.donutRendererLoaded = function(runner) {
#                 iframe.runner = runner;
#                 iframe.runner([["http://m.facebook.com",2164],["http://m.facebook.com/",1684],["https://www.facebook.com/",1592],["https://m.facebook.com/",368],["https://t.co/wLjPd17VbA",254],["https://apple.news/A0KaSgxGZQ9OTRh6J6z703w",252],["https://l.facebook.com/",174],["https://www.google.com/",161],["http://www.smartnews.com/",109],["https://lm.facebook.com/",48],["https://search.yahoo.com/",43],["http://news.mynewswire.co/",23],["https://apple.news/A0KaSgxGZQ9OTRh6J6z703w?c505759d348c0b82f682ecd9c3167839",18],["https://www.google.ca/",9],["https://www.google.co.uk/",9],["Other",254]]);
#             }
#             iframe.src = "/static/graphs/templates/donut_template.html#id=donut-MQSBIQVTAWSGQJCRRQJVRKBQFXDQTNGB";
#         }());
#         </script>
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Top Referrers for News Article</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 11:59:00 to November 13, 2017 15:59:00 Local Time</h3></div>
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">referrer</th> <th class=\"cell-2\" style=\"\">referrals</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">http://m.facebook.com</td> <td class=\"cell-2\" style=\"text-align:right;\">2,164</td></tr>\n<tr><td class=\"cell-1\" style=\"\">http://m.facebook.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">1,684</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://www.facebook.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">1,592</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://m.facebook.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">368</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://t.co/wLjPd17VbA</td> <td class=\"cell-2\" style=\"text-align:right;\">254</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://apple.news/A0KaSgxGZQ9OTRh6J6z703w</td> <td class=\"cell-2\" style=\"text-align:right;\">252</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://l.facebook.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">174</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://www.google.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">161</td></tr>\n    \n    <tr><td class=\"cell-1\" style=\"\">http://www.smartnews.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">109</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://lm.facebook.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">48</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://search.yahoo.com/</td> <td class=\"cell-2\" style=\"text-align:right;\">43</td></tr>\n<tr><td class=\"cell-1\" style=\"\">http://news.mynewswire.co/</td> <td class=\"cell-2\" style=\"text-align:right;\">23</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://apple.news/A0KaSgxGZQ9OTRh6J6z703w?c505759d348c0b82f682ecd9c3167839</td> <td class=\"cell-2\" style=\"text-align:right;\">18</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://www.google.ca/</td> <td class=\"cell-2\" style=\"text-align:right;\">9</td></tr>\n<tr><td class=\"cell-1\" style=\"\">https://www.google.co.uk/</td> <td class=\"cell-2\" style=\"text-align:right;\">9</td></tr>\n    </tbody>\n")

# %%
chartMedianLoadTimesByDimension(tv.startTimeUTC,tv.endTimeUTC,dimension=:http_referrer,minPercentage=0.5)
t1 = getMedianLoadTimesByDimension(tv.startTimeUTC,tv.endTimeUTC,dimension=:http_referrer,minPercentage=0.5)
display(t1)

chartMedianLoadTimesByDimension(tv.startTimeUTC,tv.endTimeUTC,dimension=:params_r,minPercentage=0.5)
t2 = getMedianLoadTimesByDimension(tv.startTimeUTC,tv.endTimeUTC,dimension=:params_r,minPercentage=0.5)
display(t2)
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Median Load Times by http_referrer</h1><h3 class="chart_info" style="color:#ccc">Stacked Back-end and Front-end Load Times</h3><h3 class="chart_info" style="color:#ccc">From November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:50:02</h5></div>
#     <iframe id="timeSeries-PWINBGBOPXMRSJYEKBVLADLDFTGPZTNL" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#     <script>
#     (function() {
#         var iframe = document.getElementById("timeSeries-PWINBGBOPXMRSJYEKBVLADLDFTGPZTNL");
#         iframe.timeSeriesRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner([["x","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news-iranquake&utm_campaign=Content&sf166854614=1","null","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Twitter&utm_medium=Social&utm_content=link_tw20171113news-iranquake&utm_campaign=Content&sf166858006=1","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/","https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?sf166858006=1"],["data1",956.0,852.0,846.0,392.0,176.0],["data2",12779.0,10508.0,8895.0,7730.0,6582.0]],
#                 ["Back End Load Time","Front end Load Time"],
#                 ["http_referrer","Load Times (ms)"],
#                 ["bar","bar"],
#                 ["hsla(130, 61%, 50%, 0.9)","hsla(214, 86%, 60%, 0.9)"],
#                 [["data1","data2"]],
#                 [],
#                 "",
#                 [],
#                 {"axis_y_min":0}
#             );
#         }
#         iframe.src = "/static/graphs/templates/c3VizRotated_template.html#id=timeSeries-PWINBGBOPXMRSJYEKBVLADLDFTGPZTNL";
#     }());
#     </script>
# 5x3 DataFrames.DataFrame
# │ Row │ ┝━━━━━┿
# │ 1   │ │ 2   │ │ 3   │ │ 4   │ │ 5   │
#
# │ Row │ http_referrer                                                                                                                                                                                                   │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news-iranquake&utm_campaign=Content&sf166854614=1" │
# │ 2   │ "null"                                                                                                                                                                                                          │
# │ 3   │ "https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?utm_source=Twitter&utm_medium=Social&utm_content=link_tw20171113news-iranquake&utm_campaign=Content&sf166858006=1"  │
# │ 4   │ "https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/"                                                                                                                    │
# │ 5   │ "https://news.nationalgeographic.com/2017/11/iran-iraq-earthquake-2017-photos-pictures-spd/?sf166858006=1"                                                                                                      │
#
# │ Row │ Back-end Load Time │ Front-end Load Time │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 956.0              │ 12779.0             │
# │ 2   │ 852.0              │ 10508.0             │
# │ 3   │ 846.0              │ 8895.0              │
# │ 4   │ 392.0              │ 7730.0              │
# │ 5   │ 176.0              │ 6582.0              │
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Median Load Times by params_r</h1><h3 class="chart_info" style="color:#ccc">Stacked Back-end and Front-end Load Times</h3><h3 class="chart_info" style="color:#ccc">From November 13, 2017 16:59:00 to November 13, 2017 20:59:00</h3><h5 class="chart_lastCalled" style="color:#ccc">Run at November 16, 2017 01:50:11</h5></div>
#     <iframe id="timeSeries-LYOEAZNCOYLQHOYYAAVVUDZRLQRGCNBI" class="dswbiframe" width="100%" height="600" src="about:blank" scrolling="no"></iframe>
#     <script>
#     (function() {
#         var iframe = document.getElementById("timeSeries-LYOEAZNCOYLQHOYYAAVVUDZRLQRGCNBI");
#         iframe.timeSeriesRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner([["x","lm.facebook.com","m.facebook.com","www.smartnews.com","apple.news","t.co","l.facebook.com","www.facebook.com","search.yahoo.com","www.google.com","news.nationalgeographic.com","www.nationalgeographic.com"],["data1",1019.0,1035.0,486.0,426.0,860.0,729.0,645.0,173.0,307.0,514.0,479.0],["data2",22573.0,15374.0,12285.0,11014.0,8557.5,7470.0,7101.0,7090.0,6818.0,5487.0,3507.0]],
#                 ["Back End Load Time","Front end Load Time"],
#                 ["params_r","Load Times (ms)"],
#                 ["bar","bar"],
#                 ["hsla(130, 61%, 50%, 0.9)","hsla(214, 86%, 60%, 0.9)"],
#                 [["data1","data2"]],
#                 [],
#                 "",
#                 [],
#                 {"axis_y_min":0}
#             );
#         }
#         iframe.src = "/static/graphs/templates/c3VizRotated_template.html#id=timeSeries-LYOEAZNCOYLQHOYYAAVVUDZRLQRGCNBI";
#     }());
#     </script>
# 11x3 DataFrames.DataFrame
# │ Row │ referrer                      │ Back-end Load Time │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ "lm.facebook.com"             │ 1019.0             │
# │ 2   │ "m.facebook.com"              │ 1035.0             │
# │ 3   │ "www.smartnews.com"           │ 486.0              │
# │ 4   │ "apple.news"                  │ 426.0              │
# │ 5   │ "t.co"                        │ 860.0              │
# │ 6   │ "l.facebook.com"              │ 729.0              │
# │ 7   │ "www.facebook.com"            │ 645.0              │
# │ 8   │ "search.yahoo.com"            │ 173.0              │
# │ 9   │ "www.google.com"              │ 307.0              │
# │ 10  │ "news.nationalgeographic.com" │ 514.0              │
# │ 11  │ "www.nationalgeographic.com"  │ 479.0              │
#
# │ Row │ Front-end Load Time │
# ┝━━━━━┿━━━━━━━━━━━━━━━━━━━━━┥
# │ 1   │ 22573.0             │
# │ 2   │ 15374.0             │
# │ 3   │ 12285.0             │
# │ 4   │ 11014.0             │
# │ 5   │ 8557.5              │
# │ 6   │ 7470.0              │
# │ 7   │ 7101.0              │
# │ 8   │ 7090.0              │
# │ 9   │ 6818.0              │
# │ 10  │ 5487.0              │
# │ 11  │ 3507.0              │

# %% [markdown]
# ***
#
# ## How are the page views being used
#
# ***

# %%
treemapsPGD(TV,UP,SP)
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Device Type for Page Group: News Article</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 11:59:00 to November 13, 2017 15:59:00 Local Time</h3></div>
# WARNING: rep{T <: Integer}(x::AbstractVector, lengths::AbstractVector{T}) is deprecated.
#  in depwarn
# <iframe id="6e64304f-b800-4f28-9b36-54c453e1444e" class="dswbiframe" width="100%" src="about:blank" scrolling="no"></iframe>
# <script>
#     (function() {
#         var iframe = document.getElementById("6e64304f-b800-4f28-9b36-54c453e1444e");
#             iframe.treeLoaded = function(runner, id) {
#             iframe.runner = runner;
#             iframe.runner([{"data":[{"user_agent_device_type":"Mobile","load_time":15.648,"beacons":5557},{"user_agent_device_type":"Desktop","load_time":7.134,"beacons":3021},{"user_agent_device_type":"Tablet","load_time":21.883,"beacons":289}],"title":"Natgeo - All"}], id, ["user_agent_device_type"], 1, {"BV":"Bouvet Island","OM":"Oman","TF":"French Southern Territories","NO":"Norway","DO":"Dominican Republic","SR":"Suriname","BS":"Bahamas","NP":"Nepal","HM":"Heard Island and McDonald Islands","SJ":"Svalbard and Jan Mayen","EG":"Egypt","EE":"Estonia","CU":"Cuba","US":"United States","LU":"Luxembourg","CM":"Cameroon","AE":"United Arab Emirates","FR":"France","FI":"Finland","MQ":"Martinique","VG":"Virgin Islands, British","JP":"Japan","TG":"Togo","GW":"Guinea-Bissau","NF":"Norfolk Island","IE":"Ireland","TV":"Tuvalu","MX":"Mexico","GY":"Guyana","CA":"Canada","AD":"Andorra","MF":"Saint Martin","VE":"Venezuela","KN":"Saint Kitts and Nevis","SD":"Sudan","GU":"Guam","NE":"Niger","TM":"Turkmenistan","BN":"Brunei Darussalam","KZ":"Kazakhstan","CI":"Cote d\\'Ivoire","SX":"Sint Maarten","CO":"Colombia","QA":"Qatar","PG":"Papua New Guinea","LV":"Latvia","UY":"Uruguay","RO":"Romania","IM":"Isle of Man","VA":"Holy See (Vatican City State)","PA":"Panama","BI":"Burundi","CC":"Cocos (Keeling) Islands","SA":"Saudi Arabia","PF":"French Polynesia","VU":"Vanuatu","YT":"Mayotte","AU":"Australia","TR":"Turkey","WS":"Samoa","GB":"United Kingdom","GN":"Guinea","UA":"Ukraine","GT":"Guatemala","GA":"Gabon","BZ":"Belize","MS":"Montserrat","BA":"Bosnia and Herzegovina","KP":"Korea, Democratic People\\'s Republic of","SS":"South Sudan","PL":"Poland","KI":"Kiribati","PR":"Puerto Rico","HR":"Croatia","TT":"Trinidad and Tobago","PE":"Peru","MR":"Mauritania","CZ":"Czech Republic","AG":"Antigua and Barbuda","BD":"Bangladesh","MH":"Marshall Islands","MT":"Malta","BT":"Bhutan","SI":"Slovenia","AS":"American Samoa","MG":"Madagascar","MC":"Monaco","FK":"Falkland Islands (Malvinas)","IR":"Iran, Islamic Republic of","TZ":"Tanzania, United Republic of","BY":"Belarus","LC":"Saint Lucia","IQ":"Iraq","FO":"Faroe Islands","IS":"Iceland","BO":"Bolivia","SH":"Saint Helena","CW":"Curacao","CL":"Chile","DK":"Denmark","BJ":"Benin","UM":"United States Minor Outlying Islands","IN":"India","GM":"Gambia","AM":"Armenia","KW":"Kuwait","DZ":"Algeria","TJ":"Tajikistan","LK":"Sri Lanka","UG":"Uganda","ZW":"Zimbabwe","MY":"Malaysia","GD":"Grenada","O1":"Other Country","ES":"Spain","SM":"San Marino","BB":"Barbados","VN":"Vietnam","CF":"Central African Republic","DJ":"Djibouti","FJ":"Fiji","ST":"Sao Tome and Principe","GP":"Guadeloupe","NZ":"New Zealand","SY":"Syrian Arab Republic","PH":"Philippines","IL":"Israel","JE":"Jersey","IO":"British Indian Ocean Territory","KE":"Kenya","MW":"Malawi","MV":"Maldives","AW":"Aruba","HK":"Hong Kong","SZ":"Swaziland","ID":"Indonesia","AT":"Austria","LR":"Liberia","SO":"Somalia","MZ":"Mozambique","TK":"Tokelau","TW":"Taiwan","MA":"Morocco","SK":"Slovakia","SV":"El Salvador","CD":"Congo, The Democratic Republic of the","EU":"Europe","CH":"Switzerland","BL":"Saint Bartelemey","KH":"Cambodia","GQ":"Equatorial Guinea","ZA":"South Africa","GG":"Guernsey","SL":"Sierra Leone","MO":"Macao","HN":"Honduras","LI":"Liechtenstein","IT":"Italy","YE":"Yemen","SC":"Seychelles","ME":"Montenegro","CV":"Cape Verde","BE":"Belgium","NC":"New Caledonia","A1":"Anonymous Proxy","GF":"French Guiana","JO":"Jordan","GH":"Ghana","DE":"Germany","MD":"Moldova, Republic of","BQ":"Bonaire, Saint Eustatius and Saba","AO":"Angola","CK":"Cook Islands","TO":"Tonga","LT":"Lithuania","RU":"Russian Federation","AI":"Anguilla","AQ":"Antarctica","EC":"Ecuador","HT":"Haiti","EH":"Western Sahara","SE":"Sweden","CG":"Congo","PN":"Pitcairn","KG":"Kyrgyzstan","MN":"Mongolia","NG":"Nigeria","PS":"Palestinian Territory","MM":"Myanmar","ML":"Mali","LA":"Lao People\\'s Democratic Republic","PK":"Pakistan","LB":"Lebanon","WF":"Wallis and Futuna","GR":"Greece","HU":"Hungary","RS":"Serbia","BF":"Burkin ...
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Browser Family for Page Group: News Article</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 11:59:00 to November 13, 2017 15:59:00 Local Time</h3></div>
# <iframe id="4c690166-908f-47f1-9f2b-fb24cfb039b7" class="dswbiframe" width="100%" src="about:blank" scrolling="no"></iframe>
# <script>
#     (function() {
#         var iframe = document.getElementById("4c690166-908f-47f1-9f2b-fb24cfb039b7");
#             iframe.treeLoaded = function(runner, id) {
#             iframe.runner = runner;
#             iframe.runner([{"data":[{"user_agent_family":"Facebook","load_time":15.436,"beacons":4430},{"user_agent_family":"Chrome","load_time":7.0085,"beacons":2102},{"user_agent_family":"Chrome Mobile","load_time":26.368,"beacons":804},{"user_agent_family":"Mobile Safari","load_time":10.2895,"beacons":650},{"user_agent_family":"Firefox","load_time":9.253,"beacons":349},{"user_agent_family":"Safari","load_time":7.0995,"beacons":276},{"user_agent_family":"IE","load_time":6.019,"beacons":176},{"user_agent_family":"Edge","load_time":6.216,"beacons":97},{"user_agent_family":"Mobile Safari UIWebView","load_time":10.471,"beacons":71},{"user_agent_family":"Opera","load_time":10.2025,"beacons":46},{"user_agent_family":"Chrome Mobile iOS","load_time":9.346,"beacons":33},{"user_agent_family":"Opera Mini","load_time":4.848,"beacons":27},{"user_agent_family":"Android Browser","load_time":30.417,"beacons":20},{"user_agent_family":"Amazon Silk","load_time":32.607,"beacons":16},{"user_agent_family":"Edge Mobile","load_time":15.449,"beacons":12},{"user_agent_family":"Firefox Mobile","load_time":30.557,"beacons":11},{"user_agent_family":"Chromium","load_time":13.2795,"beacons":10},{"user_agent_family":"IE Mobile","load_time":72.935,"beacons":8},{"user_agent_family":"Opera Mobile","load_time":33.653,"beacons":7},{"user_agent_family":"UC Browser","load_time":60.761,"beacons":6},{"user_agent_family":"Yandex Browser","load_time":13.9975,"beacons":4},{"user_agent_family":"Firefox iOS","load_time":18.437,"beacons":3},{"user_agent_family":"BlackBerry WebKit","load_time":53.0855,"beacons":2}],"title":"Natgeo - All"}], id, ["user_agent_family"], 1, {"BV":"Bouvet Island","OM":"Oman","TF":"French Southern Territories","NO":"Norway","DO":"Dominican Republic","SR":"Suriname","BS":"Bahamas","NP":"Nepal","HM":"Heard Island and McDonald Islands","SJ":"Svalbard and Jan Mayen","EG":"Egypt","EE":"Estonia","CU":"Cuba","US":"United States","LU":"Luxembourg","CM":"Cameroon","AE":"United Arab Emirates","FR":"France","FI":"Finland","MQ":"Martinique","VG":"Virgin Islands, British","JP":"Japan","TG":"Togo","GW":"Guinea-Bissau","NF":"Norfolk Island","IE":"Ireland","TV":"Tuvalu","MX":"Mexico","GY":"Guyana","CA":"Canada","AD":"Andorra","MF":"Saint Martin","VE":"Venezuela","KN":"Saint Kitts and Nevis","SD":"Sudan","GU":"Guam","NE":"Niger","TM":"Turkmenistan","BN":"Brunei Darussalam","KZ":"Kazakhstan","CI":"Cote d\\'Ivoire","SX":"Sint Maarten","CO":"Colombia","QA":"Qatar","PG":"Papua New Guinea","LV":"Latvia","UY":"Uruguay","RO":"Romania","IM":"Isle of Man","VA":"Holy See (Vatican City State)","PA":"Panama","BI":"Burundi","CC":"Cocos (Keeling) Islands","SA":"Saudi Arabia","PF":"French Polynesia","VU":"Vanuatu","YT":"Mayotte","AU":"Australia","TR":"Turkey","WS":"Samoa","GB":"United Kingdom","GN":"Guinea","UA":"Ukraine","GT":"Guatemala","GA":"Gabon","BZ":"Belize","MS":"Montserrat","BA":"Bosnia and Herzegovina","KP":"Korea, Democratic People\\'s Republic of","SS":"South Sudan","PL":"Poland","KI":"Kiribati","PR":"Puerto Rico","HR":"Croatia","TT":"Trinidad and Tobago","PE":"Peru","MR":"Mauritania","CZ":"Czech Republic","AG":"Antigua and Barbuda","BD":"Bangladesh","MH":"Marshall Islands","MT":"Malta","BT":"Bhutan","SI":"Slovenia","AS":"American Samoa","MG":"Madagascar","MC":"Monaco","FK":"Falkland Islands (Malvinas)","IR":"Iran, Islamic Republic of","TZ":"Tanzania, United Republic of","BY":"Belarus","LC":"Saint Lucia","IQ":"Iraq","FO":"Faroe Islands","IS":"Iceland","BO":"Bolivia","SH":"Saint Helena","CW":"Curacao","CL":"Chile","DK":"Denmark","BJ":"Benin","UM":"United States Minor Outlying Islands","IN":"India","GM":"Gambia","AM":"Armenia","KW":"Kuwait","DZ":"Algeria","TJ":"Tajikistan","LK":"Sri Lanka","UG":"Uganda","ZW":"Zimbabwe","MY":"Malaysia","GD":"Grenada","O1":"Other Country","ES":"Spain","SM":"San Marino","BB":"Barbados","VN":"Vietnam","CF":"Central African Republic","DJ":"Djibouti","FJ":"Fiji","ST":"Sao Tome and Principe","GP":"Guadeloupe","NZ":"New Zealand","SY":"Syria ...
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">
td></tr>\n<tr><td class=\"cell-1\" style=\"\">Opera Mobile</td> <td class=\"cell-2\" style=\"text-align:right;\">33.653</td> <td class=\"cell-3\" style=\"text-align:right;\">7</td></tr>\n<tr><td class=\"cell-1\" style=\"\">UC Browser</td> <td class=\"cell-2\" style=\"text-align:right;\">60.761</td> <td class=\"cell-3\" style=\"text-align:right;\">6</td></tr>\n<tr><td class=\"cell-1\" style=\"\">Yandex Browser</td> <td class=\"cell-2\" style=\"text-align:right;\">13.9975</td> <td class=\"cell-3\" style=\"text-align:right;\">4</td></tr>\n<tr><td class=\"cell-1\" styl ...
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Countries for Page Group: News Article</h1><h3 class="chart_info" style="color:#ccc">November 13, 2017 11:59:00 to November 13, 2017 15:59:00 Local Time</h3></div>
# <iframe id="2ca3bc69-6d58-40ea-a980-4424ff11d713" class="dswbiframe" width="100%" src="about:blank" scrolling="no"></iframe>
# <script>
#     (function() {
#         var iframe = document.getElementById("2ca3bc69-6d58-40ea-a980-4424ff11d713");
#             iframe.treeLoaded = function(runner, id) {
#             iframe.runner = runner;
#             iframe.runner([{"data":[{"load_time":9.43,"geo_cc":"US","beacons":4341},{"load_time":11.166,"geo_cc":"CA","beacons":671},{"load_time":13.077,"geo_cc":"GB","beacons":449},{"load_time":14.849,"geo_cc":"MX","beacons":230},{"load_time":13.589,"geo_cc":"AU","beacons":178},{"load_time":13.372,"geo_cc":"DE","beacons":167},{"load_time":12.438,"geo_cc":"RO","beacons":163},{"load_time":19.478,"geo_cc":"IN","beacons":149},{"load_time":13.563,"geo_cc":"NL","beacons":120},{"load_time":19.034,"geo_cc":"PH","beacons":118},{"load_time":14.082,"geo_cc":"IT","beacons":117},{"load_time":23.6295,"geo_cc":"ZA","beacons":116},{"load_time":12.331,"geo_cc":"BG","beacons":103},{"load_time":15.035,"geo_cc":"FR","beacons":94},{"load_time":11.793,"geo_cc":"AE","beacons":89},{"load_time":10.055,"geo_cc":"SE","beacons":89},{"load_time":16.638,"geo_cc":"TR","beacons":81},{"load_time":17.179,"geo_cc":"GR","beacons":66},{"load_time":15.221,"geo_cc":"HU","beacons":64},{"load_time":24.993,"geo_cc":"PK","beacons":60},{"load_time":24.06,"geo_cc":"SA","beacons":60},{"load_time":13.6205,"geo_cc":"IE","beacons":58},{"load_time":10.185,"geo_cc":"PL","beacons":56},{"load_time":11.082,"geo_cc":"ES","beacons":55},{"load_time":8.208,"geo_cc":"CH","beacons":49},{"load_time":11.912,"geo_cc":"PT","beacons":49},{"load_time":15.073,"geo_cc":"NZ","beacons":48},{"load_time":12.061,"geo_cc":"BE","beacons":44},{"load_time":10.39,"geo_cc":"FI","beacons":43},{"load_time":14.1645,"geo_cc":"CR","beacons":42},{"load_time":20.024,"geo_cc":"KW","beacons":41},{"load_time":7.913,"geo_cc":"NO","beacons":41},{"load_time":24.773,"geo_cc":"IQ","beacons":40},{"load_time":15.0125,"geo_cc":"BR","beacons":38},{"load_time":7.234,"geo_cc":"DK","beacons":36},{"load_time":11.715,"geo_cc":"AT","beacons":36},{"load_time":12.375,"geo_cc":"HR","beacons":34},{"load_time":15.6095,"geo_cc":"UA","beacons":34},{"load_time":
/home/ubuntu/datascienceworkbench/lib/Modules/DSWBDrawing/src/DSWBDrawing.jl:811
#  in deviceTypeTreemap at /data/notebook_home/Production/Lib/Treemaps-Package-v1.0.jl:22
#  in treemapsPGD at /data/notebook_home/Production/Lib/Page-Group-Package-v1.0.jl:10
#  in include_string at loading.jl:295
#  in execute_request at /home/ubuntu/.julia/v0.4/IJulia/src/execute_request.jl:157
#  in eventloop at /home/ubuntu/.julia/v0.4/IJulia/src/eventloop.jl:8
#  in anonymous at task.jl:447
# while loading In[28], in expression starting on line 1

# %%
result10 = getAllPaths(tv.startTimeUTC, tv.endTimeUTC; n=30, f=getAbandonPaths,useurls=true);
drawSunburst(result10[1]; totalPaths=result10[3])
# Out:
# <iframe id="sb-SPAIYDZXCICRDGWWVTVNPNOWXJJRPROV" class="dswbiframe" width="100%" src="about:blank" scrolling="no"></iframe>
# <script>
#     (function() {
#         var iframe = document.getElementById("sb-SPAIYDZXCICRDGWWVTVNPNOWXJJRPROV");
#
#         iframe.sunburstRendererLoaded = function(runner) {
#             iframe.runner = runner;
#             iframe.runner({"end":"#787878","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news_iranquake&utm_campaign=Content&sf166854614=1":"#a30023","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/":"#00798f","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Twitter&utm_medium=Social&utm_content=link_tw20171113news_iranquake&utm_campaign=Content&sf166858006=1":"#00798f","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?sf166858006=1":"#00a33c","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+ng%2FNews%2FNews_Main+%28National+Geographic+News+_+Main%29":"#00f55a","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+ng%2FNews%2FNews_Main+%28National+Geographic+News+_+Main%29&utm_content=Yahoo+Search+Results":"#00adcc","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Twitter&utm_medium=Social&utm_content=link_tw20171113news_iranquake&utm_campaign=Content&sf166858006=1&utm_campaign=Bundle&utm_medium=referral&utm_source=Bundle":"#182177","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Facebook&utm_medium=Soc":"#2534bb","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=dlvr.it&utm_medium=twitter":"#3343d7","https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/azija/":"#182177"}, [["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news_iranquake&utm_campaign=Content&sf166854614=1-end",6082],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/-end",1712],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Twitter&utm_medium=Social&utm_content=link_tw20171113news_iranquake&utm_campaign=Content&sf166858006=1-end",263],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news_iranquake&utm_campaign=Content&sf166854614=1-https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news_iranquake&utm_campaign=Content&sf166854614=1-end",171],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/-https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/-end",130],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?sf166858006=1-end",48],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=Facebook&utm_medium=Social&utm_content=link_fb20171113news_iranquake&utm_campaign=Content&sf166854614=1-https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/-end",34],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/?utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+ng%2FNews%2FNews_Main+%28National+Geographic+News+_+Main%29-end",17],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/-https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/-https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_photos_pictures_spd/-end",14],["https://news.nationalgeographic.com/2017/11/iran_iraq_earthquake_2017_ ...
# Got 31 paths, reducing to top 30.

# %%
q = query(""" drop view if exists $(UP.btView);""")
q = query(""" drop view if exists $(UP.rtView);""")
;
# Out:
# [ODBC] 2BP01: ERROR: cannot drop view beacons_4744_url_details_view_prod because other objects depend on it;
# Error while executing the query
# [ODBC]: SQLExecDirect failed; Return Code: SQL_DEFAULT_ERROR
#
#  in error at ./error.jl:21
#  in ODBCQueryExecute at /home/ubuntu/.julia/v0.4/ODBC/src/backend.jl:45
#  in query at /home/ubuntu/.julia/v0.4/ODBC/src/userfacing.jl:46
#  in query at /home/ubuntu/.julia/v0.4/ODBC/src/userfacing.jl:42
