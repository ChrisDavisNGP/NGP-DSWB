# %%
using ODBC
using DataFrames
using DSWB
using Formatting

dsn = "dswb-natgeo" # Redshift esetTable(tableRt, tableType = "RESOURCE_TABLE")ndpoint
table = "beacons_4744" # beacon table name
tableRt = "beacons_4744_rt"

# Connect to Beacon Data
setRedshiftEndpoint(dsn)
setTable(tableRt, tableType = "RESOURCE_TABLE")
setTable(table)
# Out:
# Redshift endpoint set: 2017-11-20T16:07:47
# "beacons_4744"

# %%
# Time & Structures First
include("../../Lib/Include-Package-v2.1.jl")
include("Find-Any-Resources-Body-v2.0.jl")
;

# %%
#TV = timeVariables(2017,11,6,1,0,2017,11,6,23,59);
#TV = weeklyTimeVariables(days=7);
TV = yesterdayTimeVariables()
;
# Out:
# November 19, 2017 06:59:00 to November 19, 2017 16:59:00 Local Time
# November 19, 2017 11:59:00 to November 19, 2017 21:59:00 UTC Time

# %%
UP = UrlParamsInit()
UP.agentOs = "%"
UP.beaconTable = table
UP.btView = "$(table)_find_any_resource_pview_prod" #localtable
UP.deviceType = "%"
UP.limitRows = 250
UP.orderBy = "time"
UP.pageGroup = "%"   #productPageGroup
UP.resourceTable = tableRt
UP.rtView = "$(tableRt)_find_any_resource_pview_prod" #localtableRt
UP.samplesMin = 10
UP.sizeMin = 100000
UP.timeLowerMs = 2000.0
UP.timeUpperMs = 60000.0
UP.urlRegEx = "%1491649%"   #localUrl
UP.urlFull = "%"
UP.usePageLoad=false

SP = ShowParamsInit()
SP.criticalPathOnly=true
SP.desktop=true
SP.devView=false
SP.debug=false
SP.debugLevel = 0   # Tests use even numbers with > tests, make this an odd number or zero
SP.mobile=true
SP.showLines=25

SG = SoastaGraphsInit()
customer = "Nat Geo" 
SG.customer = customer
;

# %%
defaultTableFARB(TV,UP,SP)
;

# %%
resourceSummary2FARB(TV,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %</h1><h3 class="chart_info" style="color:#ccc">November 19, 2017 06:59:00 to November 19, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummaryFARB(TV,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Resource Url Pattern %</h1><h3 class="chart_info" style="color:#ccc">November 19, 2017 06:59:00 to November 19, 2017 16:59:00 Local Time</h3></div>
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr></tr></thead>\n    <tbody>\n    \n    \n    \n    </tbody>\n")

# %%
resourceSummary3FARB(TV,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %</h1><h3 class="chart_info" style="color:#ccc">November 19, 2017 06:59:00 to November 19, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummary4FARB(TV,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %</h1><h3 class="chart_info" style="color:#ccc">November 19, 2017 06:59:00 to November 19, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummary5FARB(TV,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %</h1><h3 class="chart_info" style="color:#ccc">November 19, 2017 06:59:00 to November 19, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummary6FARB(TV,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %</h1><h3 class="chart_info" style="color:#ccc">November 19, 2017 06:59:00 to November 19, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
q = query(""" drop view if exists $(UP.btView);""")
q = query(""" drop view if exists $(UP.rtView);""")
;
