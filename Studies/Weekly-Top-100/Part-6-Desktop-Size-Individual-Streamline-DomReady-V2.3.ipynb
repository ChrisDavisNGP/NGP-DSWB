# %% [markdown]
# ## Tables and Data Source setup

# %%
using ODBC
using DataFrames
using DSWB
using Formatting
using URIParser
using JSON

dsn = "dswb-natgeo" # Redshift esetTable(tableRt, tableType = "RESOURCE_TABLE")ndpoint
table = "beacons_4744" # beacon table name
tableRt = "beacons_4744_rt"

# Connect to Beacon Data
setRedshiftEndpoint(dsn)
setTable(table)
setTable(tableRt, tableType = "RESOURCE_TABLE")
;
# Out:
# Redshift endpoint set: 2017-11-12T08:00:08

# %%
# Packages

include("/data/notebook_home/Production/Lib/Include-Package-v1.0.jl")
include("/data/notebook_home/Production/Bodies/Individual-Streamline-Body-v2.0.jl")

#timeVariables(2017,5,9,16,0,2017,5,9,16,59)
weeklyTimeVariables(days=7)
#yesterdayTimeVariables()
;
# Out:
# November 4, 2017 23:59:00 to November 11, 2017 23:59:00 Local Time
# November 5, 2017 03:59:00 to November 12, 2017 04:59:00 UTC Time

# %%
# Packages

include("/data/notebook_home/Production/Bodies/Individual-Streamline-v1.2.jl")

UP = UrlParamsInit()
UP.beaconTable = table
UP.resourceTable = tableRt
UP.pageGroup = "%"
UP.urlRegEx = "%"
UP.urlFull = "%"
#UP.limitRows = 3
UP.limitRows = 250
UP.samplesMin = 10
UP.sizeMin = 10000
UP.usePageLoad=false
UP.timeLowerMs = 2000.0
UP.timeUpperMs = 60000.0
UP.orderBy = "size"
UP.deviceType = "desktop"

SP = ShowParamsInit()
SP.desktop=true
SP.mobile=false
SP.devView=false
SP.criticalPathOnly=true
SP.debug=false
SP.debugLevel = 0   # Tests use even numbers with > tests, make this an odd number or zero

LV = LocalVars(false) #useJSon = false
;

# %%
urlListDF = returnMatchingUrlTableV2(TV,UP)
if (SP.debugLevel > 4)
    beautifyDF(urlListDF[1:min(3,end),:])
end

#Minimum samples needed
newListDF = urlListDF[Bool[x > UP.samplesMin for x in urlListDF[:cnt]],:]
topUrlList = newListDF[:urlgroup]
topUrls = cleanupTopUrlTable(topUrlList)
if (SP.debugLevel > 8)
    println(topUrls)
end
;

# %%
finalUrlTableOutput(TV,UP,SP,topUrls)
;
# Out:
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Recent Urls (Sorted By Size Descending; Min Samples  10 ; Top  250  Page Views)</th> <th class=\"cell-2\" style=\"\">Time</th> <th class=\"cell-3\" style=\"\">Request Made</th> <th class=\"cell-4\" style=\"\">Page Size</th> <th class=\"cell-5\" style=\"\">Samples</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">/www.nationalgeographic.com/magazine/2017/09/holland-agriculture-sustainable-farming/%</td> <td class=\"cell-2\" style=\"text-align:right;\">11,028</td> <td class=\"cell-3\" style=\"text-align:right;\">113</td> <td class=\"cell-4\" style=\"text-align:right;\">10,591,108</td> <td class=\"cell-5\" style=\"text-align:right;\">1,641</td></tr>\n<tr><td class=\"cell-1\" style=\"\">