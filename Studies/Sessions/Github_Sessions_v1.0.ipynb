# %% [markdown]
# ## Tables and Data Source setup

# %%
using ODBC
using DataFrames
using DSWB
using Formatting
using URIParser
using JSON

dsn = "dswb-natgeo" # Redshift esetTable(tableRt, tableType = "RESOURCE_TABLE")ndpoint
table = "beacons_4744" # beacon table name
tableRt = "beacons_4744_rt"

# Connect to Beacon Data
setRedshiftEndpoint(dsn)
setTable(table)
setTable(tableRt, tableType = "RESOURCE_TABLE")
;
# Out:
# Redshift endpoint set: 2017-06-06T13:13:41

# %%
# LIbraries

run(`rm -rf NGP-DSWB`)
run(`git clone https://github.com/ChrisDavisNGP/NGP-DSWB.git`)
include("NGP-DSWB/Lib/Include-Package-v2.0.jl")

# tv structure created in include above, so init time here
#timeVariables(2017,5,9,16,0,2017,5,9,16,59)
weeklyTimeVariables(days=7)
#yesterdayTimeVariables()
;
# Out:
# Cloning into 'NGP-DSWB'...
# May 29, 2017 23:59:00 to June 5, 2017 23:59:00 Local Time
# May 30, 2017 03:59:00 to June 6, 2017 03:59:00 UTC Time

# %%
# Packages

include("NGP-DSWB/NB-Lib/Individual-Streamline-v1.2.jl")

#pageGroup = "%"
pageGroup = "%"
urlRegEx = "%"
urlFull = "%"
#top10 = 10
top10 = 250
samplesMin = 10
sizeMin = 10000
#sizeMin = 0
#samplesMin = 0
usePageLoad=false
#lowerLimitMs = 1000
#upperLimitMs = 600000
lowerLimitMs = 2000.0
upperLimitMs = 60000.0
orderBy = "size"
#upperLimitMs = 120000.0
#orderBy = "time"
deviceType = ""

UP = UrlParams(table,tableRt,pageGroup,urlRegEx,urlFull,lowerLimitMs,upperLimitMs,top10,samplesMin,sizeMin,orderBy,usePageLoad,deviceType)

showJson=false
showDesktop=false
showMobile=true
showDevView=false
showCriticalPathOnly=true
showDebug=false
showDebugLevel = 0   # Tests use even numbers with > tests, make this an odd number or zero

SP = ShowParams(showDesktop,showMobile,showDevView,showCriticalPathOnly,showDebug,showDebugLevel)
;

# %%
SP.mobile = true
SP.desktop = false
UP.orderBy = "time"
if (SP.mobile)
    UP.deviceType = "mobile"
else
    UP.deviceType = "desktop"
end

urlListDF = returnMatchingUrlTableV2(TV,UP)
if (SP.debugLevel > 4)
    beautifyDF(urlListDF[1:min(3,end),:])
end

newListDF = urlListDF[Bool[x > UP.samplesMin for x in urlListDF[:cnt]],:]
topUrlList = newListDF[:urlgroup]
topUrls = cleanupTopUrlTable(topUrlList)
if (SP.debugLevel > 8)
    println(topUrls)
end
;

# %%
finalUrlTableOutput(TV,UP,SP,topUrls)
;
# Out:
# HTML{UTF8String}("    <table  class=\"dataframe-table\">\n    <thead><tr><th class=\"cell-1\" style=\"\">Recent Urls (Sorted By Time Descending; Min Samples  10 ; Top  250  Page Views)</th> <th class=\"cell-2\" style=\"\">Time</th> <th class=\"cell-3\" style=\"\">Request Made</th> <th class=\"cell-4\" style=\"\">Page Size</th> <th class=\"cell-5\" style=\"\">Samples</th></tr></thead>\n    <tbody>\n    <tr><td class=\"cell-1\" style=\"\">/ocean.nationalgeographic.com/ocean/photos/deep-sea-creatures/%</td> <td class=\"cell-2\" style=\"text-align:right;\">26,492</td> <td class=\"cell-3\" style=\"text-align:right;\">83</td> <td class=\"cell-4\" style=\"text-align:right;\">271,094</td> <td class=\"cell-5\" style=\"text-align