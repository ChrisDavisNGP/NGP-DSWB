# %%
using ODBC
using DataFrames
using DSWB
using Formatting

dsn = "dswb-natgeo" # Redshift esetTable(tableRt, tableType = "RESOURCE_TABLE")ndpoint
table = "beacons_4744" # beacon table name
tableRt = "beacons_4744_rt"

# Connect to Beacon Data
setRedshiftEndpoint(dsn)
setTable(table)
setTable(tableRt, tableType = "RESOURCE_TABLE")
# Out:
# Redshift endpoint set: 2017-06-10T16:17:21
# "beacons_4744_rt"

# %%
# Packages
include("/data/notebook_home/Production/Lib/Include-Package-v1.0.jl")
include("/data/notebook_home/Production/Bodies/Show-Requests-For-Large-Pages-Body-v1.0.jl")

timeVariables(2017,6,8,10,59,2017,6,8,12,59)
#weeklyTimeVariables(days=1)
#yesterdayTimeVariables()
;
# Out:
# June 8, 2017 10:59:00 to June 8, 2017 12:59:00 Local Time
# June 8, 2017 14:59:00 to June 8, 2017 16:59:00 UTC Time

# %%
UP = UrlParamsInit()
UP.beaconTable = table   #table
UP.resourceTable = tableRt
UP.btView = "$(table)_Large_Pages_pview_prod" #localtable
UP.rtView = "$(tableRt)_Large_Pages_pview_prod" #localtableRt
UP.pageGroup = "News Article"   #productPageGroup
UP.urlRegEx = "%"   #localUrl
UP.deviceType = "Mobile"

SG = SoastaGraphsInit()
customer = "Nat Geo" 
SG.customer = customer

SP = ShowParamsInit()
SP.debugLevel = 10;
SP.debug = true;
;

LV = LocalVars(0,0,0)
LV.linesOutput = 25
;

# %%
defaultTableSRFLP(tv,UP)
;
# Out:
# beacons_4744_Large_Pages_pview_prod count is 278730

# %%
bigPages1SRFLP(tv,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Domain Size in KB</h1></div>
# ...

# %%
bigPages2SRFLP(tv,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Big Pages (Min 727792 KB Pages)</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 10:59:00 to June 8, 2017 12:59:00 Local Time</h3></div>
# ...

# %%
bigPages3SRFLP(tv,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Big Pages By Average Size (Min 727792 KB Pages)</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 10:59:00 to June 8, 2017 12:59:00 Local Time</h3></div>
# ...

# %%
bigPages4SRFLP(tv,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Big Pages With Session ID (Min 727792 KB)</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 10:59:00 to June 8, 2017 12:59:00 Local Time</h3></div>
# ...

# %%
bigPages5SRFLP(tv,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Big Pages With Timestamp (Min 727792 KB)</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 10:59:00 to June 8, 2017 12:59:00 Local Time</h3></div>
# ...

# %%
bigPages6SRFLP(tv,UP,LV)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Big Pages Details (Min 727792 KB)</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 10:59:00 to June 8, 2017 12:59:00 Local Time</h3></div>
# ...

# %%
q = query(""" drop view if exists $(UP.btView);""")
q = query(""" drop view if exists $(UP.rtView);""")
;
