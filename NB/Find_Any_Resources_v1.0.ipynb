# %%
using ODBC
using DataFrames
using DSWB
using Formatting

dsn = "dswb-natgeo" # Redshift esetTable(tableRt, tableType = "RESOURCE_TABLE")ndpoint
table = "beacons_4744" # beacon table name
tableRt = "beacons_4744_rt"

# Connect to Beacon Data
setRedshiftEndpoint(dsn)
setTable(tableRt, tableType = "RESOURCE_TABLE")
setTable(table)
# Out:
# Redshift endpoint set: 2017-06-09T14:19:17
# "beacons_4744"

# %%
# Packages
include("/data/notebook_home/Production/Lib/Include-Package-v1.0.jl")
include("/data/notebook_home/Production/Bodies/Find-Any-Resources-Body-v1.0.jl")

#timeVariables(2017,5,5,13,30,2017,5,5,13,59);
#weeklyTimeVariables(days=1);
yesterdayTimeVariables()
;
# Out:
# June 8, 2017 06:59:00 to June 8, 2017 16:59:00 Local Time
# June 8, 2017 10:59:00 to June 8, 2017 20:59:00 UTC Time

# %%
UP = UrlParamsInit()
UP.beaconTable = table   #table
UP.resourceTable = tableRt
UP.btView = "$(table)_find_any_resource_pview_prod" #localtable
UP.rtView = "$(tableRt)_find_any_resource_pview_prod" #localtableRt
UP.pageGroup = "News Article"   #productPageGroup
UP.urlRegEx = "%"   #localUrl
UP.deviceType = "Mobile"

SG = SoastaGraphsInit()
customer = "Nat Geo" 
SG.customer = customer
;
resourceUrl = "%adapt%"
linesOutput = 25
minimumEncoded = 100000
;

# %%
defaultTableFARB(tv,UP)
;
# Out:
# beacons_4744_find_any_resource_pview_prod count is 198200

# %%
resourceSummaryFARB(UP;linesOut=linesOutput,minEncoded=minimumEncoded)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Resource Url Pattern %adapt%</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 06:59:00 to June 8, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummary2FARB(tv,UP;linesOut=linesOutput,minEncoded=minimumEncoded)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %adapt%</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 06:59:00 to June 8, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummary3FARB(tv,UP;linesOut=linesOutput,minEncoded=minimumEncoded)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %adapt%</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 06:59:00 to June 8, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummary4FARB(tv,UP;linesOut=linesOutput,minEncoded=minimumEncoded)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %adapt%</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 06:59:00 to June 8, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummary5FARB(tv,UP;linesOut=linesOutput,minEncoded=minimumEncoded)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %adapt%</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 06:59:00 to June 8, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
resourceSummary6FARB(tv,UP;linesOut=linesOutput,minEncoded=minimumEncoded)
;
# Out:
# <div class="dswbOutputText"><h1 class="chart_title" style="color:#ccc">Raw Resource Url Pattern %adapt%</h1><h3 class="chart_info" style="color:#ccc">June 8, 2017 06:59:00 to June 8, 2017 16:59:00 Local Time</h3></div>
# ...

# %%
q = query(""" drop view if exists $(UP.btView);""")
q = query(""" drop view if exists $(UP.rtView);""")
;
